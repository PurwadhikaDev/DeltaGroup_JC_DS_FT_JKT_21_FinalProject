# %% [markdown]
# # **MACHINE LEARNING PREDICT:**
# # **E-COMMERCE CUSTOMER CHURN**

# %% [markdown]
# ## **Business Problem Understanding**
# ---

# %% [markdown]
# ### **A. Latar Belakang**

# %% [markdown]
# Dalam era bisnis modern, di mana teknologi terus berkembang pesat, E-commerce telah menjadi salah satu pilar utama dalam perekonomian global. E-commerce, singkatan dari perdagangan elektronik, mencakup berbagai kegiatan bisnis yang dilakukan secara online, mulai dari pembelian dan penjualan produk hingga layanan konsumen. Sebagai sarana yang memungkinkan konsumen untuk berbelanja dan berinteraksi dengan perusahaan tanpa batasan geografis, E-commerce telah membuka pintu untuk peluang pertumbuhan yang signifikan.
#
# Dalam konteks bisnis E-commerce modern, retensi pelanggan menjadi faktor krusial yang sangat memengaruhi kelangsungan perusahaan di tengah persaingan yang semakin ketat. Profitabilitas suatu perusahaan E-commerce tidak hanya ditentukan oleh kualitas produk atau layanan yang ditawarkan, tetapi juga oleh kemampuan perusahaan dalam mempertahankan dan memperluas basis pelanggan yang setia. Pengembangan metode pembelajaran yang dapat mencegah dan mengurangi customer churn (pelanggan yang beralih) menjadi esensial dalam strategi bisnis E-commerce.
#
# Faktor-faktor yang menyebabkan *customer churn* (pelanggan beralih) dalam konteks bisnis E-commerce sangat beragam dan dapat dipengaruhi oleh berbagai elemen. Beberapa faktor utama yang dapat memicu pelanggan untuk meninggalkan suatu platform E-commerce melibatkan kombinasi dari aspek layanan, pengalaman pengguna, dan dinamika pasar. Berikut adalah beberapa faktor yang dapat memengaruhi *customer churn*:
#
# 1. **Kualitas Layanan Pelanggan:**
#    - Kurangnya respons atau penanganan yang lambat terhadap pertanyaan dan masalah pelanggan dapat membuat mereka kecewa dan mencari alternatif yang lebih responsif.
#
# 2. **Pengalaman Pengguna yang Buruk:**
#    - Antarmuka yang rumit, lambatnya waktu pemuatan halaman, atau kesulitan dalam navigasi dapat merugikan pengalaman pengguna, yang pada gilirannya dapat menjadi penyebab pelanggan meninggalkan platform.
#
# 3. **Harga dan Penawaran Bersaing:**
#    - Penawaran harga yang tidak kompetitif atau kurangnya diskon dan promosi dapat membuat pelanggan mencari pilihan yang lebih ekonomis di tempat lain.
#
# 4. **Ketidakpuasan Produk atau Layanan:**
#    - Produk atau layanan yang tidak sesuai dengan harapan pelanggan atau adanya masalah kualitas dapat menjadi alasan kuat untuk beralih ke penyedia yang lebih memenuhi kebutuhan mereka.
#
# 5. **Komunikasi yang Tidak Efektif:**
#    - Kurangnya komunikasi yang efektif, termasuk kurangnya pemberitahuan tentang penawaran khusus atau pembaruan produk, dapat membuat pelanggan merasa diabaikan.
#
# 6. **Perubahan Preferensi Pelanggan:**
#    - Perubahan kebutuhan atau preferensi pelanggan seiring waktu dapat membuat mereka mencari penyedia yang lebih cocok dengan perubahan tersebut.
#
# 7. **Persaingan yang Intensif:**
#    - Keberadaan pesaing yang menawarkan layanan serupa dengan harga lebih baik atau dengan keunggulan lainnya dapat memotivasi pelanggan untuk mencari alternatif.
#
# 8. **Ketidakpuasan terhadap Kebijakan Bisnis:**
#    - Kebijakan pengembalian yang tidak fleksibel, biaya tambahan yang tidak terduga, atau masalah terkait dengan kebijakan bisnis dapat menyebabkan ketidakpuasan dan *customer churn*.
#
# Hal ini menunjukkan bahwa setiap bisnis, termasuk perusahaan E-commerce, harus menjaga hubungan dengan pelanggan yang setia. Evaluasi terhadap pelanggan yang meninggalkan layanan dalam jangka waktu tertentu, atau yang dikenal sebagai *customer churn*, merupakan langkah penting. Kehilangan pelanggan yang loyal dapat merugikan karena perusahaan harus mengeluarkan biaya hingga 16 kali lipat lebih besar untuk menggantikan pelanggan tersebut dengan pelanggan baru. Dengan memiliki wawasan tentang pelanggan mana yang berisiko untuk beralih, perusahaan dapat menyusun strategi pemasaran yang lebih efektif dan memberikan perhatian khusus kepada kelompok pelanggan ini."

# %% [markdown]
# ### **B. Pernyataan Masalah**

# %% [markdown]
# Perusahaan e-commerce ingin mengetahui customer churn atau pelanggan yang tidak menggunakan jasa perusahaan lagi, sehingga dapat menimbulkan kerugian bagi perusahaan. Oleh karena itu, perusahaan perlu melakukan prediksi terhadap customer, agar sebelum costumer benar-benar churn, perusahaan dapat menjangkau customer tersebut dengan memberikan layanan yang lebih baik, seperti memberikan promo yang menarik. Namun, sebaiknya promo diberikan kepada orang yang tepat. Dengan demikian, perusahaan dapat menghindari kerugian yang akan terjadi akibat kehilangan pelanggan.
#
# Pelanggan loyal yang *churn* dapat merugikan perusahaan apabila tidak dihiraukan, untuk itu perusahaan perlu mempertahankan aktivitas pelanggan loyal di platform E-commerce. Salah satu cara yang dapat dilakukan adalah memberikan promosi. Namun, biaya dan sumber daya yang dikeluarkan menjadi kurang efektif apabila promosi dilakukan tanpa strategi.
#
#
# Perusahaan e-commerce menghadapi tantangan dalam memprediksi dan mencegah customer churn, sehingga mereka perlu mengembangkan strategi yang cerdas untuk mengidentifikasi pelanggan yang berisiko beralih. Hal ini memungkinkan perusahaan memberikan promosi yang tepat waktu dan kepada target yang sesuai, menghindari kerugian akibat kehilangan pelanggan loyal, dan memaksimalkan efektivitas penggunaan sumber daya promosi.

# %% [markdown]
# ### **C. Tujuan**

# %% [markdown]
# Berdasarkan permasalahan diatas, perusahaan perusahaan ingin memiliki kemampuan untuk memprediksi kemungkinan seorang pelanggan akan berhenti menggunakan berlanggan atau tidak, sehingga dapat memfokuskan upaya-upaya retensi pada pelanggan yang terindikasi untuk churn.
#
# **Stakeholder: Marketing Team dan Customer Retention Team (CRT)**

# %% [markdown]
# ### **D. Pendekatan Analitik**

# %% [markdown]
# Pendekatan analitik yang dilakukan berupa pembuatan, evaluasi, dan implementasi model machine learning klasifikasi yang dapat memprediksi apabila pelanggan akan *churn* atau tidak berdasarkan riwayat data sebelumnya.

# %% [markdown]
# ### **E. Metrik Evaluasi**

# %% [markdown]
# Target:
# 0 (Negatif) : Pelanggan tidak *churn*
# 1 (Positif) : Pelanggan *churn*
# - **True Positive (TP)**: Pelanggan diprediksi dan kenyataannya melakukan churn
# - **False Positive (FP)**: Pelanggan diprediksi melakukan churn, namun pada kenyataannya customer tidak melakukan churn
# - **False Negative (FN)**: Pelanggan diprediksi tidak melakukan churn, namun pada kenyataannya customer melakukan churn
# - **True Negative (TN)**: Pelanggan diprediksi dan kenyataannya tidak melakukan churn
#
# Dalam melakukan prediksi, kesalahan dapat terjadi, yaitu:
# - **Type 1 Error** : False Positive
#     - Konsekuensi : Perusahaan mengeluarkan biaya pada pelanggan yang kurang tepat.
# - **Type 2 Error** : False Negative
#     - Konsekuensi : Hilangnya pelanggan loyal
#
# Dikarenakan biaya mencari pelanggan yang baru lebih besar dari pada biaya mempertahankan pelanggan yang ada,model yang telah dibuat harus mampu mengurangi kerugian perusahaan akibat kehilangan pelanggan atau mengurangi kesalahan prediksi False Negatif. Namun, perlu juga dijaga agar perusahaan tidak menghabiskan biaya yang tidak diperlukan untuk memberikan promosi kepada pelanggan yang sebenarnya tidak berisiko (False Positive). Oleh karena itu, kita menggunakan metrik utama yaitu **F2 score**.
#
# F2 score adalah metrik evaluasi klasifikasi yang memperhitungkan presisi dan recall. Nilai F2 score didasarkan pada parameter beta, di mana jika beta lebih besar dari 1, maka lebih menekankan recall daripada presisi. Metrik ini berguna untuk menilai kinerja model klasifikasi, terutama dalam kasus di mana kesalahan False Negatif lebih kritis daripada False Positive.

# %% [markdown]
# ## **Data Understanding**
# ---

# %% [markdown]
# ### **Import Data**

# %%
 # !pip install category_encoders

# %%
pip install shap

# %%
#Import Library
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

# Statistics
from scipy.stats import normaltest

# Train test split
from sklearn.model_selection import train_test_split

# Preprocessing & Feature Engineering
from sklearn.preprocessing import OneHotEncoder
from category_encoders import BinaryEncoder, OrdinalEncoder
from sklearn.preprocessing import RobustScaler
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
import category_encoders as ce
from sklearn.compose import ColumnTransformer

# Resampler untuk Data Imbalance
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler, NearMiss

# Modeling : algoritma ML
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import VotingClassifier, StackingClassifier, RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# Cross validation untuk menentukan algoritma terbaik
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV, train_test_split, cross_val_score

# Metrics untuk klasifikasi
from sklearn.metrics import confusion_matrix
from sklearn.metrics import fbeta_score, make_scorer
from sklearn.metrics import f1_score, classification_report, confusion_matrix, precision_recall_curve
from sklearn.metrics import fbeta_score, make_scorer

#from scipy.stats import normaltest, chi2_contingency, mannwhitneyu, ttest_ind,shapiro

# Hyperparameter Tuning
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# SHAP

import shap

#Ignore warning
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_excel('E Commerce Dataset.xlsx', sheet_name='E Comm')
data
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 0          50001      1     4.0         Mobile Phone         3
# 1          50002      1     NaN                Phone         1
# 2          50003      1     NaN                Phone         1
# 3          50004      1     0.0                Phone         3
# 4          50005      1     0.0                Phone         1
# ...          ...    ...     ...                  ...       ...
# 5625       55626      0    10.0             Computer         1
# 5626       55627      0    13.0         Mobile Phone         1
# 5627       55628      0     1.0         Mobile Phone         1
# 5628       55629      0    23.0             Computer         3
# 5629       55630      0     8.0         Mobile Phone         1
#
#       WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 0                 6.0           Debit Card  Female             3.0
# 1                 8.0                  UPI    Male             3.0
# ...

# %% [markdown]
# ### **Aspek-Aspek Dalam Data**

# %% [markdown]
# Dataset milik perusahaan E-Commerce online terkemuka. Sebuah perusahaan ritel online (E-commerce) ingin mengetahui pelanggan yang akan melakukan churn, sehingga mereka dapat mendekati pelanggan untuk menawarkan beberapa promo. Dataset berisikan profil dan riwayat transaksi pelanggan.

# %%
#Menampilkan deskripsi setiap kolom
col_desc = pd.read_excel('E Commerce Dataset.xlsx')
col_desc.iloc[:,1:]
# Out:
#       Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0         1     4.0         Mobile Phone         3              6.0
# 1         1     NaN                Phone         1              8.0
# 2         1     NaN                Phone         1             30.0
# 3         1     0.0                Phone         3             15.0
# 4         1     0.0                Phone         1             12.0
# ...     ...     ...                  ...       ...              ...
# 5625      0    10.0             Computer         1             30.0
# 5626      0    13.0         Mobile Phone         1             13.0
# 5627      0     1.0         Mobile Phone         1             11.0
# 5628      0    23.0             Computer         3              9.0
# 5629      0     8.0         Mobile Phone         1             15.0
#
#      PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# ...

# %% [markdown]
# ### **Informasi Data**

# %%
# Menampilkan informasi data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5366 non-null   float64
#  3   PreferredLoginDevice         5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5379 non-null   float64
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5375 non-null   float64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
# ...

# %%
# Menampilkan jumlah baris dan kolom
data.shape
# Out:
# (5630, 20)

# %%
# Menunjukkan statistik deskriptif masing-masing kolom
display(data.describe(), data.describe(include='object'))
# Out:
#          CustomerID        Churn       Tenure     CityTier  WarehouseToHome  \
# count   5630.000000  5630.000000  5366.000000  5630.000000      5379.000000
# mean   52815.500000     0.168384    10.189899     1.654707        15.639896
# std     1625.385339     0.374240     8.557241     0.915389         8.531475
# min    50001.000000     0.000000     0.000000     1.000000         5.000000
# 25%    51408.250000     0.000000     2.000000     1.000000         9.000000
# 50%    52815.500000     0.000000     9.000000     1.000000        14.000000
# 75%    54222.750000     0.000000    16.000000     3.000000        20.000000
# max    55630.000000     1.000000    61.000000     3.000000       127.000000
#
#        HourSpendOnApp  NumberOfDeviceRegistered  SatisfactionScore  \
# count     5375.000000               5630.000000        5630.000000
# mean         2.931535                  3.688988           3.066785
# std          0.721926                  1.023999           1.380194
# ...

# %%
data.columns
# Out:
# Index(['CustomerID', 'Churn', 'Tenure', 'PreferredLoginDevice', 'CityTier',
#        'WarehouseToHome', 'PreferredPaymentMode', 'Gender', 'HourSpendOnApp',
#        'NumberOfDeviceRegistered', 'PreferedOrderCat', 'SatisfactionScore',
#        'MaritalStatus', 'NumberOfAddress', 'Complain',
#        'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
#        'DaySinceLastOrder', 'CashbackAmount'],
#       dtype='object')

# %% [markdown]
# Dari data diatas dapat diketahui beberapa hal:
# - Terdapat 5630 baris dan 20 kolom pada dataset
# - Data numerik dengan variabel quantitatif antara lain Tenure, Warehouse to Home, Hour Spend On App, Number Of Device Registered, Number Of Address, Order Amount Hike From last Year, Coupon Used, Order Count, Day Since Last Order, dan Cashback Amount.
# - Data numerik yang menunjukkan yes or no atau bersifat qualitatif adalah Complain dan Churn.
# - Data numerik yang menunjukkan qualitatif dengan scale ordinal adalah City Tier dan Satisfaction Score.
# - Data kategorik antara lain Preferred Login Device, Preferred Payment Mode, Gender, Prefered Order Cat, dan Marital Status.
# - Dari info dataset terlihat ada beberapa missing value, yang akan ditindak-lanjuti di data cleaning.

# %% [markdown]
# ## **Data Cleaning**
# ---

# %% [markdown]
# **Tujuan** : Mencari anomali data dan menanggulangi anomali tersebut.
#
# Langkah-langkah yanng dilakukan dalam *data cleaning* adalah:
# 1. Melihat informasi dataset termasuk tipe data, unique value, dan jumlah unique value dari setiap kolom.
# 2. Mengubah tipe data dari tiap kolom yang sekiranya belum sesuai.
# 3. Mengecek adanya *missing value* serta menanggulangi *missing value* yang terdapat dalam kolom data.
# 4. Melihat adanya *duplicate values* dan melakukan analisis.
# 5. Menganalisis outliers yang terdapat dalam dataset.

# %% [markdown]
# #### **Informasi Dataset**

# %% [markdown]
# Pertama kita akan melihat informasi detail menegnai dataset yang berisi data unik dari masing-masing fitur, melihat apakah data yang terduplikat, serta melihat apakah ada value pada dataset yang *typo*.

# %%
#Menampilkan detail informasi dari setiap kolom, yaitu:
# 1. Nama kolom
# 2. Tipe data
# 3. Jumlah Missing Value
# 4. Persentase jumlah Missing Value
# 5. Jumlah unique value
# 6. Sampel unique value

list_data = []
for i in data.columns :
    list_data.append([
        i, #nama kolom
        data[i].dtype, #tipe data dari setiap kolom
        data[i].isna().sum(), #jumlah missing value
        round((data[i].isna().sum()/len(data)*100),2), #persentase missing value
        data[i].nunique(), #jumlah unique value
        list(data[i].drop_duplicates()) #sampel unique value
    ])

pd.DataFrame(list_data, columns = ['Kolom', 'Tipe Data', 'null', 'nullPct', 'Unique', 'Sampel Unique'])
# Out:
#                           Kolom Tipe Data  null  nullPct  Unique  \
# 0                    CustomerID     int64     0     0.00    5630
# 1                         Churn     int64     0     0.00       2
# 2                        Tenure   float64   264     4.69      36
# 3          PreferredLoginDevice    object     0     0.00       3
# 4                      CityTier     int64     0     0.00       3
# 5               WarehouseToHome   float64   251     4.46      34
# 6          PreferredPaymentMode    object     0     0.00       7
# 7                        Gender    object     0     0.00       2
# 8                HourSpendOnApp   float64   255     4.53       6
# 9      NumberOfDeviceRegistered     int64     0     0.00       6
# 10             PreferedOrderCat    object     0     0.00       6
# 11            SatisfactionScore     int64     0     0.00       5
# 12                MaritalStatus    object     0     0.00       3
# ...

# %% [markdown]
# #### **Duplicate Data**

# %% [markdown]
# **Mengecek Duplikasi Data Berdasarkan CustomerID**

# %%
#totalbaris
data['CustomerID'].nunique()
# Out:
# 5630

# %%
#melihat panjang digit customerID
panjang = data['CustomerID'].map(str).apply(len)
panjang
# Out:
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#        ..
# 5625    5
# 5626    5
# 5627    5
# 5628    5
# 5629    5
# Name: CustomerID, Length: 5630, dtype: int64

# %%
(panjang == 5).value_counts()
# Out:
# True    5630
# Name: CustomerID, dtype: int64

# %%
#melihat apakah isi dari data semua berbentuk angka (0-9) dan tidak mengandung karakter apapun
data['CustomerID'].astype(str).str.contains('\d+\S+').value_counts()
# Out:
# True    5630
# Name: CustomerID, dtype: int64

# %% [markdown]
# **Hasil :**
# 1. Tidak ada ID yang duplikat pada data.
# 2. Panjang digit sama semua yaitu 5 digit.
# 3. Data semua berbentuk angka (0-9) dan tidak ada mengandung karakter.

# %% [markdown]
# **Mengecek Duplikasi Data Berdasarkan Keseluruhan**

# %%
# Melihat Jumlah Data Duplikat
Duplikat = data.duplicated().sum()
PersentaseDup = round((data.duplicated().sum()/data.shape[0])*100,2)
print (f'Data duplikat : {Duplikat}, Persentase Data Duplikat: {PersentaseDup}')
# Out:
# Data duplikat : 0, Persentase Data Duplikat: 0.0

# %% [markdown]
# Hasil : Tidak terdapat duplikasi data pada keseluruhan dataset

# %% [markdown]
# #### **Missing Value**

# %% [markdown]
# Setelah menghapus data duplikat, selanjutnya kita akan menanggulangi missing value yang terdapat dalam dataset.

# %%
# Melihat Missing Value masing-masing kolom
data.isna().sum()
# Out:
# CustomerID                       0
# Churn                            0
# Tenure                         264
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    265
# CouponUsed                     256
# OrderCount                     258
# DaySinceLastOrder              307
# CashbackAmount                   0
# dtype: int64

# %% [markdown]
# Missing value akan divisualisasi dengan *library missingno* untuk mempermudah pemilihan metode yang tepat dalam mengatasi *missing value*.

# %%
# Melihat missing value dengan matrix plot
msno.matrix(data)
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['CustomerID', 'Churn', 'Tenure', 'PreferredLoginDevice', 'CityTier',
#        'WarehouseToHome', 'PreferredPaymentMode', 'Gender', 'HourSpendOnApp',
#        'NumberOfDeviceRegistered', 'PreferedOrderCat', 'SatisfactionScore',
#        'MaritalStatus', 'NumberOfAddress', 'Complain',
#        'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
#        'DaySinceLastOrder', 'CashbackAmount'],
#       dtype='object')

# %% [markdown]
# Data kategorik antara lain Preferred Login Device, Preferred Payment Mode, Gender, Prefered Order Cat, dan Marital Status.
# Data numerik yang menunjukkan yes or no atau bersifat qualitatif adalah Complain dan Churn.

# %% [markdown]
# Terlihat bahwa pola *missing value* cukup acak. Oleh karena itu untuk mengisi missing value perlu dilihat korelasi antar kolomnya.

# %%
# Melihat korelasi kolom variabel numerik
plt.figure(figsize=(12,8))
sns.heatmap(data[['Tenure', 'WarehouseToHome', 'HourSpendOnApp', 'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount', 'DaySinceLastOrder', 'CityTier', 'NumberOfDeviceRegistered', 'SatisfactionScore', 'NumberOfAddress', 'CashbackAmount']].corr('spearman'), annot= True, linewidths= 1)
# Out:
# <Axes: >

# %% [markdown]
# Dari heatmap diatas dapat kita lihat kolom 'Tenure', 'WarehouseToHome', 'HourSpendOnApp', 'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount', 'DaySinceLastOrder' yang memiliki missing value memiliki korelasi tertinggi dengan 'CashbackAmount', sehingga pengisian missing value dengan metode IterativeImputer dengan kolom 'CashbackAmount'.
#
# Metode iteratif digunakan untuk menghasilkan perkiraan yang lebih akurat daripada metode pengisian nilai yang sederhana (Mean/Median/Mode Imputer). Metode imputasi iteratif dapat melibatkan langkah-langkah berulang di mana nilai-nilai yang hilang diisi berdasarkan perkiraan awal, dan proses tersebut diulang hingga konvergensi.

# %%
# Mengisi missing value dengan IterativeImputer
kolom_imp = data[['Tenure', 'WarehouseToHome', 'HourSpendOnApp', 'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount', 'DaySinceLastOrder', 'CashbackAmount']]

imputer = IterativeImputer(max_iter=10)
imp_bed = imputer.fit_transform(kolom_imp)

# Memasukan imputasi kedalam kolom yang berisi missing value
data['Tenure'] = imp_bed[:, 0].round().astype(float)
data['WarehouseToHome'] = imp_bed[:, 1].round().astype(float)
data['HourSpendOnApp'] = imp_bed[:, 2].round().astype(float)
data['OrderAmountHikeFromlastYear'] = imp_bed[:, 3].round().astype(float)
data['CouponUsed'] = imp_bed[:, 4].round().astype(float)
data['OrderCount'] = imp_bed[:, 5].round().astype(float)
data['DaySinceLastOrder'] = imp_bed[:, 6].round().astype(float)
data['CashbackAmount'] = imp_bed[:, 7].round().astype(float)

# %%
# Mengecek missing value setelah imputasi
data.isna().sum()
# Out:
# CustomerID                     0
# Churn                          0
# Tenure                         0
# PreferredLoginDevice           0
# CityTier                       0
# WarehouseToHome                0
# PreferredPaymentMode           0
# Gender                         0
# HourSpendOnApp                 0
# NumberOfDeviceRegistered       0
# PreferedOrderCat               0
# SatisfactionScore              0
# MaritalStatus                  0
# NumberOfAddress                0
# Complain                       0
# OrderAmountHikeFromlastYear    0
# CouponUsed                     0
# OrderCount                     0
# DaySinceLastOrder              0
# CashbackAmount                 0
# dtype: int64

# %% [markdown]
# Hasil : data sudah tidak memiliki missing value.

# %%
data
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 0          50001      1     4.0         Mobile Phone         3
# 1          50002      1     5.0                Phone         1
# 2          50003      1     5.0                Phone         1
# 3          50004      1     0.0                Phone         3
# 4          50005      1     0.0                Phone         1
# ...          ...    ...     ...                  ...       ...
# 5625       55626      0    10.0             Computer         1
# 5626       55627      0    13.0         Mobile Phone         1
# 5627       55628      0     1.0         Mobile Phone         1
# 5628       55629      0    23.0             Computer         3
# 5629       55630      0     8.0         Mobile Phone         1
#
#       WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 0                 6.0           Debit Card  Female             3.0
# 1                 8.0                  UPI    Male             3.0
# ...

# %% [markdown]
# #### **Outliers**

# %% [markdown]
# Beberapa model nanti yang akan digunakan ketika *modeling* memiliki sifat yang sensitif terhadap outlier seperti Logistic Regression, K-Nearest Neighbour, dsb. Oleh karena itu perlu dilakukan analisis terhadap outlier.

# %%
# Membuat variabel baru berisi kolom-kolom numerik kontinu
outliers_numerik = data[['Tenure', 'WarehouseToHome', 'HourSpendOnApp', 'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount', 'DaySinceLastOrder', 'CityTier', 'NumberOfDeviceRegistered', 'SatisfactionScore', 'NumberOfAddress', 'CashbackAmount']]

# Menampilkan Outliers dengan Boxplot
plt.figure(figsize=(20,20))
for x, kolom in enumerate(outliers_numerik, 1):
    plt.subplot(4, 3, x)  # Menggunakan x sebagai indeks subplot
    sns.boxplot(data=data[kolom], orient='horizontal') #visualisasi outliers dengan boxplot
    plt.title(f'Boxplot Kolom {kolom}') #judul boxplot
    plt.xlabel(kolom)

plt.tight_layout()
plt.show()

# %% [markdown]
# Dari masing-masing Variable terlihat jelas bahwasannya ada outlier. Hal ini bisa di identifikasi dari adanya titik titik yang berada jauh dari gambar boxplotnya. Dari plot diatas dapat kita simpulkan hanya variabel SatisfactionScore saja yang tidak ada outliernya. Setelah kita mengetahui variable mana saja yang terdapat Outlier, selanjutnya kita akan atasi Outlier dengan menggunakan metode interquartile range (IQR).

# %%
# Menampilkan lower bound (quartil bawah), upper bound (quartil atas), outlier, dan persentase outlier
def outliers(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - (1.5 * IQR)
    upper_bound = Q3 + (1.5 * IQR)
    condition = (data[column] < lower_bound) | (data[column] > upper_bound)
    outliers = data[condition]
    return lower_bound, upper_bound, outliers

for column in outliers_numerik:
    lower_bound, upper_bound, data_outliers = outliers(data, column)
    data_outliers_count = len(data_outliers)
    persentase_outliers = round(data_outliers_count / len(data[column]) * 100, 2)

    print(f'Hasil pada kolom "{column}" yaitu, Lower bound = {round(lower_bound, 2)}, Upper bound = {round(upper_bound, 2)}, Total outliers = {data_outliers_count}, dan Persentase outliersnya = {persentase_outliers}')
# Out:
# Hasil pada kolom "Tenure" yaitu, Lower bound = -15.0, Upper bound = 33.0, Total outliers = 4, dan Persentase outliersnya = 0.07
# Hasil pada kolom "WarehouseToHome" yaitu, Lower bound = -7.5, Upper bound = 36.5, Total outliers = 2, dan Persentase outliersnya = 0.04
# Hasil pada kolom "HourSpendOnApp" yaitu, Lower bound = 0.5, Upper bound = 4.5, Total outliers = 6, dan Persentase outliersnya = 0.11
# Hasil pada kolom "OrderAmountHikeFromlastYear" yaitu, Lower bound = 5.5, Upper bound = 25.5, Total outliers = 33, dan Persentase outliersnya = 0.59
# Hasil pada kolom "CouponUsed" yaitu, Lower bound = -0.5, Upper bound = 3.5, Total outliers = 700, dan Persentase outliersnya = 12.43
# Hasil pada kolom "OrderCount" yaitu, Lower bound = -2.0, Upper bound = 6.0, Total outliers = 750, dan Persentase outliersnya = 13.32
# Hasil pada kolom "DaySinceLastOrder" yaitu, Lower bound = -5.5, Upper bound = 14.5, Total outliers = 62, dan Persentase outliersnya = 1.1
# ...

# %% [markdown]
# Berdasarkan analisis sebelumnya, outlier dalam setiap kolom data tidak akan dihapus, karena dianggap sebagai nilai yang wajar apabila memiliki nilai variansi yang tinggi. Meskipun demikian, beberapa kolom akan dikelompokkan untuk mempermudah proses analisis data.

# %% [markdown]
# #### **Pengelompokan Data**

# %% [markdown]
# Pada tahap ini kita akan mengelompokkan dan mengubah label pada beberapa data agar strukturnya lebih terorganisir dan memudahkan proses analisis data

# %%
# Replace values in 'PreferedOrderCat' column
data['PreferedOrderCat'].replace(['Mobile'], 'Mobile Phone', inplace=True)

# Replace values in 'PreferredPaymentMode' column
data['PreferredPaymentMode'].replace(['E wallet', 'UPI'], 'Digital Payment', inplace=True)
data['PreferredPaymentMode'].replace('CC', 'Credit Card', inplace=True)
data['PreferredPaymentMode'].replace('COD', 'Cash on Delivery', inplace=True)

# Replace values in 'PreferredLoginDevice' column
data['PreferredLoginDevice'].replace(['Mobile Phone', 'Phone'], 'Mobile Phone', inplace=True)

# %% [markdown]
# Dalam fase ini, kami telah melakukan pengelompokan berikut:
# - Pada kolom 'PreferedOrderCat' ditemukan dua kategori yang serupa, yakni mobile phone dan mobile, sehingga kategori Mobile diubah namanya mejadi Mobile Phone.
# - Pada kolom 'PreferredPaymentMode' kategori E Wallet dan UPI diubah menjadi Digital Payment, CC diubah menjadi Credit Card, serta COD diubah menjadi Cash on Delivery.
# - Pada kolom 'PreferredLoginDevice' ditemukan dua kategori yang serupa, yakni mobile phone dan mobile, sehingga kami memutuskan untuk menggabungkannya menjadi satu, yaitu Mobile Phone.

# %% [markdown]
# Pada bagian kode berikut, dilakukan proses penggandaan data yang telah melalui tahap data cleaning, dengan tujuan memisahkan data yang akan digunakan untuk Analisis Eksploratif Data (EDA) dan pemodelan. Dengan melakukan langkah ini, kita dapat memastikan bahwa dataset yang digunakan untuk eksplorasi tidak terpengaruh oleh proses pemodelan, sehingga memberikan hasil yang lebih akurat dan relevan dalam menganalisis faktor-faktor yang mempengaruhi churn.

# %%
datamodel=data.copy()

# %% [markdown]
# ## **Exploratory Data Analysis**
# ---

# %% [markdown]
# Sebelum dilakukan analisis perlu dilihat distribusi data dari setiap kolom numerik untuk melihat apakah data terdistribusi normal atau tidak normal. Apabila diketahui distribusi tidak normal atau skewed, maka digunakan median sebagai nilai tengah, dan apabila terdistribusi normal maka mean digunakan sebagai nilai tengah.

# %% [markdown]
# #### **Analisis Distribusi Data**

# %%
# Menampilkan distribusi data dengan test normalitas

# import fungsi dari library untuk uji normalitas
from scipy.stats import kstest

# Nama kolom yang akan diuji normalitas
kolomNormalitas = data[['Tenure', 'WarehouseToHome', 'HourSpendOnApp', 'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount', 'DaySinceLastOrder', 'CityTier', 'NumberOfDeviceRegistered', 'SatisfactionScore', 'NumberOfAddress', 'CashbackAmount']]

# Membuat list kosong untuk menaruh hasil uji distribusi dari setiap kolom
list = []

# Melakukan uji normalitas pada setiap kolom dalam kolomNormalitas
for col in kolomNormalitas:
    ks, p_value = kstest(data[col], 'norm')
    distribusi = 'distribusi normal' if p_value > 0.05 else 'distribusi tidak normal'
    list.append([col, distribusi])

print('Hasil Uji Normalitas')

for result in list:
    print(f'Kolom "{result[0]}" memiliki {result[1]}')
# Out:
# Hasil Uji Normalitas
# Kolom "Tenure" memiliki distribusi tidak normal
# Kolom "WarehouseToHome" memiliki distribusi tidak normal
# Kolom "HourSpendOnApp" memiliki distribusi tidak normal
# Kolom "OrderAmountHikeFromlastYear" memiliki distribusi tidak normal
# Kolom "CouponUsed" memiliki distribusi tidak normal
# Kolom "OrderCount" memiliki distribusi tidak normal
# Kolom "DaySinceLastOrder" memiliki distribusi tidak normal
# Kolom "CityTier" memiliki distribusi tidak normal
# Kolom "NumberOfDeviceRegistered" memiliki distribusi tidak normal
# Kolom "SatisfactionScore" memiliki distribusi tidak normal
# Kolom "NumberOfAddress" memiliki distribusi tidak normal
# Kolom "CashbackAmount" memiliki distribusi tidak normal

# %% [markdown]
# Berdasarkan uji normalitas pada kolom 'Tenure', 'WarehouseToHome', 'HourSpendOnApp', 'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount', 'DaySinceLastOrder', 'CityTier', 'NumberOfDeviceRegistered', 'SatisfactionScore', 'NumberOfAddress', 'CashbackAmount' diperoleh **distribusi data tidak normal**. Maka untuk mencari nilai tengah dalam analisis data menggunakan **median**.

# %% [markdown]
# Analisis yang dilakukan bertujuan untuk memahami karakteristik dari pelanggan yang *churn* dengan melihat proporsi pelanggan yang *churn* dan yang tidak *churn*.

# %% [markdown]
# #### **1. Proporsi Pelanggan Churn dan Tidak Churn**

# %%
# Perbandingan pelanggan yang tidak churn dan churn
print('Jumlah pelanggan yang tidak churn dan churn')
print(data['Churn'].value_counts())

# Persentase pelanggan yang churn dan tidak churn
print('Persentase pelanggan yang tidak churn dan churn')
print(data['Churn'].value_counts()/len(data['Churn'])*100)
# Out:
# Jumlah pelanggan yang tidak churn dan churn
# 0    4682
# 1     948
# Name: Churn, dtype: int64
# Persentase pelanggan yang tidak churn dan churn
# 0    83.161634
# 1    16.838366
# Name: Churn, dtype: float64

# %%
plt.figure().suptitle('E-commerce Customer Churn', fontsize=20)

plt.subplot(1, 1, 1)
sns.countplot(data=data, x='Churn', palette=['tab:blue', 'tab:red'])
sns.color_palette('pastel')

plt.xticks(ticks=[0, 1], labels=['Not Churn', 'Churn'])

for p in plt.gca().patches:
    plt.gca().annotate(f'\n{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.tight_layout()
plt.show()

# %%
# Menghitung jumlah churn dan non-churn
churn_counts = data['Churn'].value_counts()

# Membuat pie chart
plt.figure(figsize=(5, 5))
plt.pie(churn_counts, labels=['Not Churn', 'Churn'], autopct='%1.1f%%', colors=['tab:blue', 'tab:red'], startangle=90)

# Menambahkan judul
plt.title('Perbandingan Churn dan Not Churn')

# Menampilkan pie chart
plt.show()

# %% [markdown]
# Dari hasil diatas dapat dilihat bahwa terdapat **imbalance data**. Hal ini dikarenakan proporsi kelas yang timpang dengan proporsi tidak churn, yaitu  83,2% dan proporsi churn 16.8%. Data yang imbalance dapat berdampak buruk pada model machine learning yang akan dibuat terutama pada saat memprediksi kelas dengan jumlah yang lebih sedikit atau kelas minoritas. Oleh karena itu, perlu dilakukan metode resampling dengan metode Random Under Sampling dan Near Miss yaitu untuk menurunkan kelas mayoritas mengikuti kelas minoritas pada saat modeling, atau Random Over Sampling yang berfungsi untuk meningkatkan kelas minoritas mengikuti kelas mayoritas.

# %% [markdown]
# #### **2. Churn berdasarkan Status pernikahan**

# %% [markdown]
# Dalam analisis ini, kita akan meneliti apakah status pernikahan memiliki dampak terhadap keputusan pelanggan untuk berhenti menggunakan layanan (*churn*) atau tetap setia.

# %%
# Membuat countplot dengan kategori 'MaritalStatus' dan menggunakan 'Churn' sebagai hue
ax = sns.countplot(x='MaritalStatus', hue='Churn', data=data, palette=['tab:blue', 'tab:red'], dodge=False)

# Menambahkan label pada bar chart
for p in ax.patches:
    ax.annotate(f'\n{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

# Mengubah legend menjadi 'Churn' dan 'Not Churn'
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles, labels=['Not Churn', 'Churn'])

# Menambahkan judul
plt.title('Jumlah Churn berdasarkan Status Pernikahan')

# Menampilkan grafik
plt.show()

# %%
# Menghitung jumlah churn berdasarkan status pernikahan
churn_by_marital_status = data.groupby(['MaritalStatus', 'Churn']).size().unstack()

# Menghitung total per kategori status pernikahan
total_by_marital_status = data['MaritalStatus'].value_counts()

# Menghitung presentase churn berdasarkan status pernikahan
churn_percentage_by_marital_status = (churn_by_marital_status[1] / total_by_marital_status) * 100

# Membuat tiga pie chart
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

# Loop untuk setiap kategori status pernikahan
for i, status in enumerate(churn_percentage_by_marital_status.index):
    axes[i].pie([churn_percentage_by_marital_status[status], 100 - churn_percentage_by_marital_status[status]],
               labels=['Churn', 'Non-Churn'], autopct='%1.1f%%', colors=['tab:red', 'tab:blue'], startangle=90)
    axes[i].set_title(f'Churn Percentage - {status}')

# Menampilkan pie charts
plt.show()

# %% [markdown]
# Dari grafik tersebut, dapat diamati bahwa status pernikahan cukup berpengaruh terhadap kecenderungan pelanggan untuk berhenti menggunakan layanan atau mempertahankan langganan. Berdasarkan data yang tercatat:
# - Pelanggan dengan status "Single" memiliki jumlah churn yang paling tinggi dibandingkan dengan status pernikahan lainnya, sebanyak 480 pelanggan.
# - Meskipun jumlah pelanggan yang "Married" lebih banyak daripada "Single", namun jumlah churn pada kategori ini relatif lebih rendah dibandingkan dengan pelanggan "Single" sebanyak 344 pelanggan.
# - Pelanggan dengan status "Divorced" menunjukkan tingkat churn yang sedang, berada di antara kategori "Single" dan "Married", sebanyak 122 pelanggan.
#
# Pemahaman ini dapat memberikan wawasan kepada perusahaan untuk menyesuaikan strategi retensi berdasarkan status pernikahan pelanggan, khususnya dalam mengatasi tingkat churn yang tinggi pada segmen "Single" dengan menyesuaikan penawaran atau layanan mereka untuk lebih tepat memenuhi kebutuhan dan preferensi dari segmen pelanggan ini.

# %% [markdown]
# #### **3. Churn Berdasarkan Jenis Kelamin**

# %% [markdown]
# Pada tahap ini kita akan melihat pengaruh jenis kelamin terhadap tingkat churn.

# %%
# Menghitung jumlah keseluruhan gender
total_by_gender = data['Gender'].value_counts()

# Menghitung jumlah churn berdasarkan gender
churn_by_gender = data.groupby(['Gender', 'Churn']).size().unstack()

# Memilih data hanya untuk mereka yang churn
churned_data = churn_by_gender[1].fillna(0)  # Mengisi nilai NaN dengan 0 untuk churned
not_churned_data = churn_by_gender[0].fillna(0)  # Mengisi nilai NaN dengan 0 untuk not churned

# Membuat DataFrame untuk menggabungkan data churn dan total gender
combined_data = pd.DataFrame({'Churned': churned_data, 'Not Churned': not_churned_data})

# Membuat stacked bar chart
ax = combined_data.plot(kind='bar', stacked=True, color=['tab:red', 'tab:blue'])

# Menambahkan label di atas setiap bar
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

# Menambahkan judul
plt.title('Jumlah Churn Berdasarkan Jenis Kelamin')

# Menampilkan legenda
plt.legend(title='Churn', loc='upper left')

# Menampilkan grafik
plt.show()

# %%
# Menghitung presentase churn berdasarkan gender
churn_percentage_by_gender = (churned_data / total_by_gender) * 100

# Membuat dua pie chart
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Pie chart untuk laki-laki
axes[0].pie([float(churn_percentage_by_gender['Male']), 100 - float(churn_percentage_by_gender['Male'])], labels=['Churn', 'Non-Churn'], autopct='%1.1f%%', colors=['tab:red', 'tab:blue'], startangle=90)
axes[0].set_title('Persentase Churn Pada Jenis Kelamin Laki-Laki')

# Pie chart untuk perempuan
axes[1].pie([float(churn_percentage_by_gender['Female']), 100 - float(churn_percentage_by_gender['Female'])], labels=['Churn', 'Non-Churn'], autopct='%1.1f%%', colors=['tab:red', 'tab:blue'], startangle=90)
axes[1].set_title('Persentase Churn Pada Jenis Kelamin Perempuan')

# Menampilkan pie charts
plt.show()

# %% [markdown]
# 1. Dari grafik 'Jumlah Churn Berdasarkan Jenis Kelamin' dapat dilihat bahwa terdapat lebih banyak pelanggan laki-laki dibandingkan dengan pelanggan perempuan, dengan jumlah 3348 banding 2246. Hal ini dapat mengindikasikan bahwa lebih banyak laki-laki yang tertarik dengan layanan yang ditawarkan oleh bisnis.
#
# 2. Meskipun jumlah pelanggan laki-laki yang lebih besar, pelanggan perempuan memiliki rasio churn yang relatif lebih rendah dibandingkan dengan pelanggan laki-laki.
#     - Rasio churn untuk pelanggan perempuan adalah 348/2246 = 15.5%
#     - Rasio churn untuk pelanggan laki-laki adalah 600/3348 = 17.9%
#
# Ini menunjukkan bahwa meskipun bisnis menarik lebih banyak pelanggan laki-laki, perlu diperhatikan faktor-faktor yang mungkin mempengaruhi kecenderungan churn pada pelanggan laki-laki untuk mempertahankan basis pelanggan yang stabil.
# Dengan mengetahui perbedaan rasio churn antara pelanggan laki-laki dan perempuan, strategi pemasaran dan retensi dapat disesuaikan lebih lanjut untuk memahami alasan di balik tren ini.

# %% [markdown]
# #### **4. Pengaruh Tenure Pelanggan Terhadap Churn**

# %%
dataeda  = data.copy()
dataeda['Tenure']=dataeda['Tenure'].astype(int)
dataeda['Tenure']=dataeda['Tenure'].astype(object)

# Membuat fungsi untuk melakukan transformasi pada data
def transformasi(angka):
    if 13 <= angka <= 18:
        return '13-18 Month'
    elif 19 <= angka <= 24:
        return '19-24 Month'
    elif angka > 24:
        return 'Over 2 Year'

    else:
        return str(angka)

# Menerapkan transformasi pada kolom 'angka'
dataeda['transformed'] = dataeda['Tenure'].apply(transformasi)

# Hitung value counts pada kolom "Tenure"
value_counts_tenure = dataeda['transformed'].value_counts()

# Hitung value counts pada kolom "Tenure" jika Churn == 1
value_counts_churned_tenure = dataeda[dataeda['Churn'] == 1]['transformed'].value_counts()

# Hitung rasio
ratio_churned_tenure = value_counts_churned_tenure / value_counts_tenure

# Buat DataFrame hasil
result_df = pd.DataFrame({
    'Jumlah': value_counts_tenure,
    'Jumlah Churned': value_counts_churned_tenure,
    'Rasio Churned': ratio_churned_tenure
})

# Isi nilai NaN dengan 0 (jika ada)
result_df = result_df.fillna(0)

# Urutkan indeks sesuai dengan urutan yang diinginkan
desired_order =['Over 2 Year', '19-24 Month', '13-18 Month'] + [str(i) for i in range(12, -1, -1)]
result_df = result_df.reindex(desired_order)

# Format kolom 'Rasio Churned' menjadi dua angka desimal
result_df['Rasio Churned'] = result_df['Rasio Churned'].apply(lambda x: round(x, 4))
result_df['Jumlah Churned'] = result_df['Jumlah Churned'].astype(int)

# %%
# Buat stacked proportional horizontal bar graph dengan label rasio persen
fig, ax = plt.subplots(figsize=(10, 10))

# Plot bar untuk 'Jumlah Churned'
bars1 = ax.barh(result_df.index, result_df['Jumlah Churned'], label='Churned', color='orange')

# Plot bar untuk 'Jumlah - Jumlah Churned'
bars2 = ax.barh(result_df.index, result_df['Jumlah'] - result_df['Jumlah Churned'], left=result_df['Jumlah Churned'], label='Total Customer per Tenure', color='blue')

# Tambahkan label dan judul
ax.set_ylabel('Tenure')
ax.set_xlabel('Jumlah')
ax.set_title('Rasio Churn Berdasarkan Tenure')


# Tambahkan label pada setiap bar
for bar1, bar2, label in zip(bars1, bars2, result_df['Rasio Churned']):
    xval = bar1.get_width() + 50
    ax.text(xval, bar1.get_y() + bar1.get_height() / 2, f'{label * 100:.2f}%', ha='center', va='center', color='white',fontweight='bold')

# Tambahkan label pada setiap bar
for bar1, bar2, churn, total in zip(bars1, bars2, result_df['Jumlah Churned'],result_df['Jumlah'] ):
    xval = bar1.get_width() + bar2.get_width() +60
    label = f'({churn}/{total})'
    ax.text(xval, bar1.get_y() + bar1.get_height() / 2, f'{label}', ha='center', va='center', color='black')


ax.legend()

# Sesuaikan batas-batas subplot untuk memperbesar kotak subplot tanpa mengubah ukuran total grafik
plt.xlim(0, 1100)

# Tampilkan grafik
plt.show()

# %% [markdown]
# Grafik tersebut menampilkan distribusi pelanggan berdasarkan durasi (tenure) mereka dan proporsi yang berhenti berlangganan, dengan pelanggan yang berhenti ditandai dengan warna kuning sementara yang tetap berlangganan ditampilkan dengan warna biru.
#
# Tingginya tingkat churn pada periode awal (0-1 bulan) memperlihatkan ketidakmampuan dalam mempertahankan pelanggan pada fase fase awal penggunaan layanan. Namun, seiring berjalannya waktu, terlihat penurunan jumlah pelanggan yang berhenti, menggambarkan upaya yang berhasil dalam mempertahankan pelanggan yang telah menggunakan layanan untuk jangka waktu yang lebih lama.

# %% [markdown]
# ##### **4a. Penggunaan *Device* Dalam Setiap Tenure**

# %%
#  Membuat kanvas grafik dengan lebar yang diinginkan
plt.figure(figsize=(12, 6))

# Menambahkan judul keseluruhan
plt.suptitle('Penggunaan Layanan Per Tenure Customer', fontsize=16)

# Filter the DataFrame for Tenure less than 12
filtered_df = dataeda

# Calculate the average 'HourSpendOnApp' for each 'Tenure' and 'PreferredLoginDevice' combination
average_hour_spend_per_tenure_device = filtered_df.groupby(['transformed', 'PreferredLoginDevice'])['HourSpendOnApp'].mean().reset_index()

# Create a barplot with 'Tenure' on x-axis, 'HourSpendOnApp' on y-axis, and 'PreferredLoginDevice' as hue
desired_order = [str(i) for i in range(13)] + ['13-18 Month', '19-24 Month', 'Over 2 Year']
sns.barplot(data=average_hour_spend_per_tenure_device, x='transformed', y='HourSpendOnApp',order= desired_order,ci=None, color='lightblue')
plt.xlabel('Tenure')
plt.xticks(rotation=45)
plt.ylabel('Rata -rata penggunaan layanan per jam')

# Tampilkan grafik
plt.show()

# %% [markdown]
# Grafik ini memperlihatkan grafik penggunaan rata-rata per jam pennggunaan layanan pada setiap tenurenya
#
# Pengguna pada tenure 0 terlihat memiliki rata rata penggunaan lebih rendah dibandingkan dengan tenure lainnya, mengindikasikan kurangnya pemanfaatan layanan pada fase awal pengguna dalam memanfaatkan layanan. Oleh karena itu perlunya upaya dalam meningkatkan kesadaran pelanggan terhadap pemanfaatan layanan sebagai upaya mengurangi jumlah pelanggan yang churn.

# %% [markdown]
# ##### **4b. Pengaruh Cashback terhadap Churn pada lama berlangganan(tenure)**

# %%
# Membuat kanvas grafik dengan lebar yang diinginkan
plt.figure(figsize=(12, 6))

# Menambahkan judul keseluruhan
plt.suptitle('Cashback Per Tenure Pelanggan', fontsize=16)

# Create a barplot with the desired order on the y-axis and light blue color
sns.barplot(data=dataeda, x='transformed', y='CashbackAmount', estimator='average', order=desired_order, color='lightblue',ci=None)

# Add vertical lines for the medians of 'CashbackAmount' for 'Churn' values 1 and 0
median_churn_1 = dataeda[dataeda['Churn'] == 1]['CashbackAmount'].median()
median_churn_0 = dataeda[dataeda['Churn'] == 0]['CashbackAmount'].median()

plt.axhline(y=median_churn_1, color='r', linestyle='--', label='Median Cashback Churn')
plt.axhline(y=median_churn_0, color='b', linestyle='--', label='Median Cashback Tidak Churn')

plt.ylabel('Median Cashback')
plt.xlabel('Tenure')
plt.xticks(rotation=45)
plt.title('Median Cashback yang diterima pengguna per Tenure')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), fancybox=True, shadow=True, ncol=2)

plt.show()

# %% [markdown]
# Grafik ini memperlihatkan median cashback per periode tenurnya dengan garis referensi median pelanggan churn dan tidak churn.
#
# Terlihat dari cashback yang diterima pada pelanggan tenure awal (0-2 bulan) dibawah median dari cashback yang diterima pelanggan yang tidak churn, sehingga mengindikasikannya pentingnya mengevaluasi jumlah cashback yang diberikan pada awal awal penggunaan e-commerce dalam mempertahankan pelanggan dan meningkatkan kesadaran pelanggan terhadap keuntungan cashback sebagai upaya mengurangi jumlah pelanggan yang churn.

# %% [markdown]
# ##### **4c. Skor Kepuasan Pelanggan Berdasarkan Tenure**

# %%
# Filter hanya baris dengan nilai 'transformed' 0 atau 1
filtered_data = dataeda[(dataeda['transformed']== '0') | (dataeda['transformed'] == '1')]

# Mengelompokkan berdasarkan kolom 1 dan menghitung frekuensi setiap nilai kolom 2
grouped_data = filtered_data.groupby(['transformed', 'SatisfactionScore']).size().unstack(fill_value=0)

# Normalisasi untuk menghitung proporsi
proporsi_data = grouped_data.div(grouped_data.sum(axis=1), axis=0)

# Menghitung proporsi dalam satuan persentase
proporsi_data_persen = proporsi_data * 100

# Filter hanya baris dengan nilai 'transformed' 0 atau 1
dataeda1 =dataeda[dataeda['Churn']==1]

filtered_data1 = dataeda1[(dataeda1['transformed']== '0') | (dataeda1['transformed'] == '1')]

# Mengelompokkan berdasarkan kolom 1 dan menghitung frekuensi setiap nilai kolom 2
grouped_data1 = filtered_data1.groupby(['transformed', 'SatisfactionScore']).size().unstack(fill_value=0)

# Normalisasi untuk menghitung proporsi
proporsi_data1 = grouped_data1.div(grouped_data1.sum(axis=1), axis=0)

# Menghitung proporsi dalam satuan persentase
proporsi_data_persen1 = proporsi_data1 * 100

# %%
# Membuat palet warna gradasi dari merah ke kuning
color_palette = np.linspace(0, 1, len(grouped_data.columns))
custom_colors = plt.cm.copper(color_palette)

# Plot stacked bar chart
ax = proporsi_data_persen.plot(kind='barh', stacked=True, color=custom_colors, width=0.8, figsize=(12,6))

# Menambahkan label persentase dan nilai dari grouped_data pada setiap bar
for i, container in enumerate(ax.containers):
    for j, bar in enumerate(container):
        # Memastikan indeks tidak melebihi ukuran grouped_data
        if i < len(grouped_data.columns) and j < len(grouped_data.index):
            # Mendapatkan nilai sesuai dengan posisi bar pada grouped_data
            nilai = grouped_data.iloc[j, i]  # Baris dan kolom diubah
            nilaichurned = grouped_data1.iloc[j, i]
            # Menghitung persentase dari nilai terhadap total
            persentase = (nilai / grouped_data.iloc[j].sum()) * 100
            # Menambahkan label yang mencakup nilai dan persentase
            ax.text(bar.get_x() + bar.get_width() / 2, bar.get_y() + bar.get_height() / 2,
                    f'{persentase:.1f}%\n({nilaichurned} \n churn \n/\n{nilai})', color='white',
                    ha='center', va='center', size=10, weight='bold')


# Menetapkan sumbu x menjadi interval 10
plt.xticks(np.arange(0, 110, 10))


# Menambahkan label dan judul
plt.xlabel('Proporsi Satisafaction Score')
plt.ylabel('Tenure')
plt.title('Proporsi Satisfaction Score terhadap Dua Tenure dengan Persentase Churn Tertinggi')

# Menambahkan legenda
plt.legend(title='Satisfaction Score', bbox_to_anchor=(1.05, 1), loc='upper left')

# Sesuaikan batas-batas subplot untuk memperbesar kotak subplot tanpa mengubah ukuran total grafik
plt.xlim(0, 110)

# Menampilkan grafik
plt.show()

# %% [markdown]
# Pada grafik tersebut memperlihatkan proporsi satisfaction score terhadap 2 tenure dengan churn rate tertinggi (tenure 0 dan 1).
#
# Banyaknya pengguna tidak melanjutkan penggunaan ke bulan ke 2 dapat disebabkan oleh skor kepuasan yang rendah, sehingga pengguna mulai meninggalkan layanan dimulai dari awal penggunaan hingga bulan 1(Churn Tertinggi).

# %% [markdown]
# ##### **4d.Penggunaan Kupon per Tenure**

# %%
# Melakukan pengelompokan berdasarkan kolom Tenure dan menghitung jumlah OrderCount untuk setiap kelompok
ordercount_by_tenure = dataeda.groupby('transformed')['OrderCount','CouponUsed','CashbackAmount'].sum().reset_index()

# Mengganti urutan DataFrame sesuai dengan urutan yang diinginkan
desired_order = ['Over 2 Year', '19-24 Month', '13-18 Month'] + [str(i) for i in range(12, -1, -1)]
ordercount_by_tenure = ordercount_by_tenure.set_index('transformed').loc[desired_order].reset_index()

# # Menampilkan hasil pengelompokan dengan urutan yang diinginkan
# print(ordercount_by_tenure)

ordercount_by_tenure = pd.DataFrame(ordercount_by_tenure)

ordercount_by_tenure['Coupon Transaction Ratio'] = ordercount_by_tenure['CouponUsed'] / ordercount_by_tenure['OrderCount']
ordercount_by_tenure['Coupon Transaction Ratio'] = ordercount_by_tenure['Coupon Transaction Ratio'].apply(lambda x: round(x, 4))
# ordercount_by_tenure['Cashback Transaction Ratio']= ordercount_by_tenure['CashbackAmount']/  ordercount_by_tenure['OrderCount']
# ordercount_by_tenure['Cashback Transaction Ratio']= ordercount_by_tenure['Cashback Transaction Ratio'].apply(lambda x: round(x, 2))


ordercount_by_tenure[['OrderCount', 'CouponUsed', 'CashbackAmount']] = ordercount_by_tenure[['OrderCount', 'CouponUsed', 'CashbackAmount']].astype(int)
# ordercount_by_tenure

# %%
# Buat stacked proportional horizontal bar graph dengan label rasio persen
fig, ax = plt.subplots(figsize=(12, 8))

# Plot bar untuk 'Jumlah Churned'
bars1 = ax.barh(ordercount_by_tenure['transformed'], ordercount_by_tenure['CouponUsed'], label='Total Coupon Used', color='orange')

# Plot bar untuk 'Jumlah - Jumlah Churned'
bars2 = ax.barh(ordercount_by_tenure['transformed'], ordercount_by_tenure['OrderCount'] - ordercount_by_tenure['CouponUsed'], left=ordercount_by_tenure['CouponUsed'], label='Total Order Count ', color='blue')

# Tambahkan label dan judul
ax.set_ylabel('Tenure')
ax.set_xlabel('Transaksi')
ax.set_title('Rasio Tenure dalam Transaksi Menggunakan Kupon')


# Tambahkan label pada setiap bar
for bar1, bar2, label in zip(bars1, bars2, ordercount_by_tenure['Coupon Transaction Ratio']):
    xval = bar1.get_width()-100
    ax.text(xval, bar1.get_y() + bar1.get_height() / 2, f'{label * 100:.0f}%', ha='center', va='center', color='white',fontweight='bold')

# Tambahkan label pada setiap bar
for bar1, bar2, coupon, total in zip(bars1, bars2, ordercount_by_tenure['CouponUsed'],ordercount_by_tenure['OrderCount'] ):
    xval = bar1.get_width() + bar2.get_width() +250
    label = f'({coupon}/{total})'
    ax.text(xval, bar1.get_y() + bar1.get_height() / 2, f'{label}', ha='center', va='center', color='black')


ax.legend()

# Sesuaikan batas-batas subplot untuk memperbesar kotak subplot tanpa mengubah ukuran total grafik
plt.xlim(0, 4250)


# Tampilkan grafik
plt.show()

# %% [markdown]
# Grafik diatas memperlihatkan jumlah order dan proporsi pengunaan kupon pada setiap masa tenurenya, pada grafik ini transaksi menggunakan kupon direpresentasikan dengan warna kuning dan transaksi yang tidak menggunakan kupon dipresentasikan dengan warna biru.
#
# Diketahui penggunaan layanan pada tenure 0, penggunaan layanan cenderung rendah sejalan dengan jumlah order yang rendah pada masa awal penggunaan layanan, mengindikasikan pelanggan masih dalam fase perkenalan dengan layanan yang diberikan.
# Lalu pada tenure selanjutnya peningkatan order juga meningkat sesuai dengan penggunaan layanan tersebut namun pada tenure 1 yang juga memiliki rasio churn tinggi, penggunaan kupon meningkat menjadi  68% dari keseluruhan transaksi pada pelanggan tenure 1. Mengindikasikan meskipun penggunaan kupon tinggi namun tidak membuat pelanggan tidak churn.

# %% [markdown]
# #### **5. Churn berdasarkan Last Order**

# %% [markdown]
# Pada langkah selanjutnya, akan dilakukan analisis untuk menentukan apakah pesanan terakhir yang dilakukan oleh pelanggan berpengaruh terhadap potensi untuk churn. Proses awal melibatkan pengelompokan pesanan terakhir pelanggan berdasarkan rentang waktu mingguannya.

# %%
# Membuat list kosong untuk menyimpan kategori 'LastOrderGroup'
last_order_group_list = []

# Looping untuk memetakan 'DaySinceLastOrder' ke 'LastOrderGroup'
for days in data['DaySinceLastOrder']:
    if days <= 7:
        last_order_group_list.append('1 Week')
    elif days <= 14:
        last_order_group_list.append('2 Weeks')
    elif days <= 21:
        last_order_group_list.append('3 Weeks')
    elif days <= 28:
        last_order_group_list.append('4 Weeks')
    else:
        last_order_group_list.append('More Than a Month')

# Menambahkan kolom 'LastOrderGroup' ke DataFrame
data['LastOrderGroup'] = last_order_group_list

# Menampilkan DataFrame dengan kolom 'DaySinceLastOrder' dan kolom 'LastOrderGroup'
print(data[['DaySinceLastOrder', 'LastOrderGroup']])
# Out:
#       DaySinceLastOrder LastOrderGroup
# 0                   5.0         1 Week
# 1                   0.0         1 Week
# 2                   3.0         1 Week
# 3                   3.0         1 Week
# 4                   3.0         1 Week
# ...                 ...            ...
# 5625                4.0         1 Week
# 5626                5.0         1 Week
# 5627                4.0         1 Week
# 5628                9.0        2 Weeks
# 5629                3.0         1 Week
#
# [5630 rows x 2 columns]

# %%
# Hitung value counts pada kolom "Tenure"
value_counts_LO = data['LastOrderGroup'].value_counts()

# Hitung value counts pada kolom "Tenure" jika Churn == 1
value_counts_churned_LO = data[data['Churn'] == 1]['LastOrderGroup'].value_counts()

# Hitung rasio
ratio_churned_LO = value_counts_churned_LO / value_counts_LO

# Buat DataFrame hasil
result_df = pd.DataFrame({
    'Jumlah': value_counts_LO,
    'Jumlah Churned': value_counts_churned_LO,
    'Rasio Churned': ratio_churned_LO
})

# Isi nilai NaN dengan 0 (jika ada)
result_df = result_df.fillna(0)

# Format kolom 'Rasio Churned' menjadi dua angka desimal
result_df['Rasio Churned'] = result_df['Rasio Churned'].apply(lambda x: round(x, 4))
result_df['Jumlah Churned'] = result_df['Jumlah Churned'].astype(int)

# Tampilkan hasil
print(result_df)
# Out:
#                    Jumlah  Jumlah Churned  Rasio Churned
# 1 Week               4257             809         0.1900
# 2 Weeks              1311             134         0.1022
# 3 Weeks                59               4         0.0678
# More Than a Month       3               1         0.3333

# %%
# Buat stacked proportional horizontal bar graph dengan label rasio persen
fig, ax = plt.subplots(figsize=(10, 6))

# Plot bar untuk 'Jumlah Churned'
bars1 = ax.barh(result_df.index, result_df['Jumlah Churned'], label='Churned', color='orange')

# Plot bar untuk 'Jumlah - Jumlah Churned'
bars2 = ax.barh(result_df.index, result_df['Jumlah'] - result_df['Jumlah Churned'], left=result_df['Jumlah Churned'], label='Total Customer per Last Order Group', color='blue')

# Tambahkan label dan judul
ax.set_ylabel('Last Order Group')
ax.set_xlabel('Jumlah')
ax.set_title('Churn Ratio Per Last Order Group')


# # Tambahkan label pada setiap bar
# for bar1, bar2, label in zip(bars1, bars2, result_df['Rasio Churned']):
#     xval = bar1.get_width() + 10
#     ax.text(xval, bar1.get_y() + bar1.get_height() / 2, f'{label * 100:.2f}%', ha='center', va='center', color='white',fontweight='bold')

# Tambahkan label pada setiap bar
for bar1, bar2, label in zip(bars1, bars2, result_df['Rasio Churned'] ):
    xval = bar1.get_width() + bar2.get_width() +200
    # label = f'({churn}/{total})'
    ax.text(xval, bar1.get_y() + bar1.get_height() / 2, f'{label * 100:.2f}%', ha='center', va='center', color='black')


ax.legend()

# Sesuaikan batas-batas subplot untuk memperbesar kotak subplot tanpa mengubah ukuran total grafik
plt.xlim(0, 5000)

# Tampilkan grafik
plt.show()

# %% [markdown]
# Dari data yang ada, terlihat bahwa pelanggan dengan pesanan terakhir yang dilakukan dalam waktu dekat dengan tanggal pesanan sebelumnya cenderung mengalami churn. Kemungkinan ini berkaitan dengan keluhan yang diajukan oleh pelanggan saat melakukan pesanan. Hal ini menunjukkan bahwa beberapa pelanggan mungkin hanya memanfaatkan promo yang ditawarkan oleh perusahaan, terutama mengingat tingginya jumlah churn dalam minggu pertama.

# %% [markdown]
# #### **6.Churn Berdasarkan Complain**

# %% [markdown]
# Dalam analisis ini, kita akan menganalisis apakah keluhan atau complain yang diajukan oleh pelanggan memiliki pengaruh terhadap kecenderungan mereka untuk melakukan churn.

# %%
# Filter data untuk yang keluhan tidak ada (complain = 0)
complain_data_no = data[data['Complain'] == 0]
complain_by_churn_no = complain_data_no['Churn'].value_counts()

# Filter data untuk yang keluhan ada (complain = 1)
complain_data_yes = data[data['Complain'] == 1]
complain_by_churn_yes = complain_data_yes['Churn'].value_counts()

# Membuat DataFrame untuk menggabungkan data complain=0 dan complain=1
combined_data = pd.DataFrame({'Tidak Complain': complain_by_churn_no, 'Complain': complain_by_churn_yes})

# Membuat stacked bar chart
ax = combined_data.transpose().plot(kind='bar', stacked=True, color=['tab:blue', 'tab:red'])

# Menambahkan label di atas setiap bar
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy()
    ax.annotate(f'{int(height)}', (x + width / 2, y + height / 2),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')

# Menambahkan judul
plt.title('Churn Berdasarkan Complain')

# Mengganti label legenda
ax.legend(['Churn', 'Not Churn'], title='Status')

# Mengganti label sumbu x
plt.xticks([0, 1], ['Tidak Complain', 'Complain'], rotation=0)

# Menampilkan grafik
plt.show()

# %%
# Menghitung presentase Churn untuk setiap kondisi keluhan
total_no_complain = complain_by_churn_no.sum()
total_complain = complain_by_churn_yes.sum()

percentage_no_complain = complain_by_churn_no / total_no_complain * 100
percentage_complain = complain_by_churn_yes / total_complain * 100

# Membuat pie chart
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# Pie chart untuk Tidak Complain
ax[0].pie(percentage_no_complain, labels=['Not Churned', 'Churn'], autopct='%1.1f%%',
          colors=['tab:blue', 'tab:red'], startangle=90)
ax[0].set_title('Tidak Complain')

# Pie chart untuk Complain
ax[1].pie(percentage_complain, labels=['Not Churned', 'Churn'], autopct='%1.1f%%',
          colors=['tab:blue', 'tab:red'], startangle=90)
ax[1].set_title('Complain')

# Menambahkan judul keseluruhan
plt.suptitle('Presentase Churn Berdasarkan Complain')

# Menampilkan grafik
plt.show()

# %% [markdown]
# Dari data yang disajikan, terlihat bahwa keluhan atau complain memiliki dampak signifikan terhadap keputusan pelanggan untuk melakukan churn. Sebanyak 31.7% atau 508 pelanggan dari total 1596 pelanggan yang mengajukan keluhan atau complain memutuskan untuk berhenti menggunakan layanan. Di sisi lain, hanya 10.9% atau 440 dari 4036 pelanggan yang tidak mengajukan keluhan yang memilih untuk melakukan churn.

# %% [markdown]
# #### **7.Complain Berdasarkan Kategori Pesanan**
#
# Seperti kita ketahui Complain sangat berpengaruh dalam customer melakukan churn atau tidak,maka dari itu kita akan melakukan analisa kategori product mana yang paling banyak complain agar kedepan nya bisa kita evaluasi kembali

# %%
value_counts_OrderCat = dataeda['PreferedOrderCat'].value_counts()

# Hitung value counts pada kolom "Tenure" jika Churn == 1
value_counts_complained_order = dataeda[dataeda['Complain'] == 1]['PreferedOrderCat'].value_counts()

ratio_complained_order= value_counts_complained_order/value_counts_OrderCat

result_df = pd.DataFrame({
    'Jumlah': value_counts_OrderCat,
    'Jumlah Complain': value_counts_complained_order,
    'Rasio Complain Per Preferensi Order': ratio_complained_order
})

# Format kolom 'Rasio Churned' menjadi dua angka desimal
result_df['Rasio Complain Per Preferensi Order'] = result_df['Rasio Complain Per Preferensi Order'].apply(lambda x: round(x, 4))
result_df['Jumlah Complain'] = result_df['Jumlah Complain'].astype(int)
result_df
# Out:
#                     Jumlah  Jumlah Complain  \
# Mobile Phone          2080              610
# Laptop & Accessory    2050              558
# Fashion                826              242
# Grocery                410              126
# Others                 264               68
#
#                     Rasio Complain Per Preferensi Order
# Mobile Phone                                     0.2933
# Laptop & Accessory                               0.2722
# Fashion                                          0.2930
# Grocery                                          0.3073
# Others                                           0.2576

# %%
# Buat stacked proportional horizontal bar graph dengan label rasio persen
fig, ax = plt.subplots(figsize=(10, 6))

# Plot bar untuk 'Jumlah Complain'
bars1 = ax.barh(result_df.index, result_df['Jumlah Complain'], label='Complain', color='orange')

# Plot bar untuk 'Jumlah - Jumlah Complain'
bars2 = ax.barh(result_df.index, result_df['Jumlah'] - result_df['Jumlah Complain'], left=result_df['Jumlah Complain'], label='Total Customer per Preferensi Order', color='blue')

# Tambahkan label dan judul
ax.set_ylabel('Tenure')
ax.set_xlabel('Jumlah')0
ax.set_title('Complain Ratio Per Preferensi Order')


# Tambahkan label pada setiap bar
for bar1, bar2, label in zip(bars1, bars2, result_df['Rasio Complain Per Preferensi Order']):
    xval = bar1.get_width() + 100
    ax.text(xval, bar1.get_y() + bar1.get_height() / 2, f'{label * 100:.2f}%', ha='center', va='center', color='white',fontweight='bold')

# Tambahkan label pada setiap bar
for bar1, bar2, churn, total in zip(bars1, bars2, result_df['Jumlah Complain'],result_df['Jumlah'] ):
    xval = bar1.get_width() + bar2.get_width() +150
    label = f'({churn}/{total})'
    ax.text(xval, bar1.get_y() + bar1.get_height() / 2, f'{label}', ha='center', va='center', color='black')


ax.legend()

# Sesuaikan batas-batas subplot untuk memperbesar kotak subplot tanpa mengubah ukuran total grafik
plt.xlim(0, 2400)

# Tampilkan grafik
plt.show()

# %% [markdown]
# Dari data yang telah disajikan, kategori "Grocery" memimpin dengan proporsi komplain sebanyak 30.73% dengan jumlah keluhan sebanyak 126, sementara kategori "Fashion" berada di urutan kedua dengan proporsi 29.30% dengan jumlah 242 keluhan. Informasi ini menunjukkan pentingnya melakukan evaluasi mendalam terhadap produk-produk tersebut untuk mengurangi keluhan.

# %% [markdown]
# #### **8.Churn Berdasarkan Jarak Rumah Pelanggan dengan Gudang**

# %% [markdown]
# Pada tahap ini, kita akan menganalisis apakah jarak antara rumah pelanggan dengan gudang mempengaruhi kecenderungan pelanggan untuk melakukan churn.

# %%
# Membuat kolom baru untuk kategori Warehouse to Home
data['WarehouseToHomeCategory'] = data['WarehouseToHome'].apply(lambda x: '30+' if x > 30 else f'{x:.0f}')

# Mengurutkan data berdasarkan jumlah Churn 1 yang paling banyak
sorted_df = data.groupby('WarehouseToHomeCategory')['Churn'].sum().sort_values(ascending=False).index
data['WarehouseToHomeCategory'] = pd.Categorical(data['WarehouseToHomeCategory'], categories=sorted_df, ordered=True)

valcon_WtHomeCat=data['WarehouseToHomeCategory'].value_counts()

# Hitung value counts pada kolom "Tenure" jika Churn == 1
valcon_WtHomeCatChurn = data[data['Churn'] == 1]['WarehouseToHomeCategory'].value_counts()
valcon_WtHomeCatChurn

rat_valcon_WtHomeCatChurn=valcon_WtHomeCatChurn/valcon_WtHomeCat

result_df = pd.DataFrame({
    'Jumlah': valcon_WtHomeCat,
    'Jumlah Churn': valcon_WtHomeCatChurn,
    'Rasio Churn Per Distance': rat_valcon_WtHomeCatChurn
})
# Format kolom 'Rasio Churned' menjadi dua angka desimal
result_df['Jumlah Churn'] = result_df['Jumlah Churn'].astype(int)

result_df['Rasio Churn Per Distance'] = result_df['Rasio Churn Per Distance']*100
result_df['Rasio Churn Per Distance'] = result_df['Rasio Churn Per Distance'].apply(lambda x: round(x, 2))
result_df['Rasio Churn Per Distance'] = result_df['Rasio Churn Per Distance'].astype(str) +'%'

# %%
# Buat stacked proportional horizontal bar graph dengan label rasio persen
fig, ax = plt.subplots(figsize=(12,12))

# Plot bar untuk 'Jumlah Churn'
bars1 = ax.barh(result_df.index, result_df['Jumlah Churn'], label='Churn', color='orange')

# Plot bar untuk 'Jumlah - Jumlah Churn'
bars2 = ax.barh(result_df.index, result_df['Jumlah'] - result_df['Jumlah Churn'], left=result_df['Jumlah Churn'], label='Total Customer per Distance', color='blue')

# Tambahkan label dan judul
ax.set_ylabel('Home Distance')
ax.set_xlabel('Jumlah Pelanggan')
ax.set_title('Churn Ratio Per Distance')

    # Tambahkan label pada setiap bar
for bar1, bar2, churn, total, rasio in zip(bars1, bars2, result_df['Jumlah Churn'],result_df['Jumlah'],result_df['Rasio Churn Per Distance'] ):
    xval = bar1.get_width() + bar2.get_width() +120
    label = f'{churn} Churn / {total} Pelanggan ({rasio})'
    ax.text(xval, bar1.get_y() + bar1.get_height() / 2, f'{label}', ha='center', va='center', color='black')


ax.legend(loc='lower right')
ax.invert_yaxis()

# Sesuaikan batas-batas subplot untuk memperbesar kotak subplot tanpa mengubah ukuran total grafik
plt.xlim(0, 800)

# Tampilkan grafik
plt.show()

# %% [markdown]
# Jarak antara gudang dan rumah, khususnya jarak lebih dari 30 menjadi faktor dominan yang mempengaruhi pelanggan untuk melakukan churn. Oleh karena itu, strategi promosi bisa diarahkan khususnya untuk pelanggan dengan jarak rumah yang lebih jauh untuk meminimalkan potensi churn.

# %% [markdown]
# ## **Data Splitting**
# ---

# %% [markdown]
# *Data splitting* adalah salah satu teknik yang sangat penting dalam konteks machine learning. Tujuannya adalah untuk meningkatkan performa model dan mencegah terjadinya overfitting. Hal ini dicapai dengan memisahkan dataset menjadi beberapa bagian yang memiliki tujuan khusus, seperti pelatihan model, validasi model, dan pengujian model.
#
# Dataset pelatihan digunakan untuk melatih model, dataset validasi digunakan untuk menentukan parameter terbaik bagi model, dan dataset pengujian digunakan untuk menguji seberapa baik model bekerja pada data yang belum pernah dilihat sebelumnya. Dengan pendekatan ini, kita dapat mencegah overfitting, yaitu saat model terlalu kompleks dan tidak mampu menghasilkan prediksi yang baik pada data baru.
#
# *Data splitting* dilakukan dengan data train 80% dan data test 20% dengan random state 2023, dan stratify y yang bertujuan untuk menyamakan proporsi semua target (*churn*) pada data train dan data test sama.
#
# x = features <br>
# y = target

# %%
# Membuat x (features) dan y (target)

x = datamodel.drop(columns=['Churn']) #feature
y = datamodel['Churn'] # target

# %%
# Data Splitting

xtrain,xtest,ytrain,ytest = train_test_split(
    x,
    y,
    stratify=y,
    random_state=2023,
    test_size=0.2
)

# %% [markdown]
# ## **Data Preprocessing & Feature Engineering**
# ---

# %% [markdown]
# Setelah memahami data serta melakukan data analisis, langkah-langkah yang dilakukan dalam proses preprocessing yaitu:
# 1. **Scaling**
#     - Melakukan Robust Scaling terhadap variabel numerik agar antar variabel memiliki skala yang sama. Variable numerik ialah 'Tenure', 'WarehouseToHome', 'HourSpendOnApp', 'NumberOfDeviceRegistered', 'SatisfactionScore', 'NumberOfAddress', 'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount', 'DaySinceLastOrder', dan 'CashbackAmount'.
# 2. **Encoding** :
#     - Melakukan OneHotEncoding pada kolom 'PreferredLoginDevice', 'PreferredPaymentMode', 'Gender', 'PreferedOrderCat', 'MaritalStatus', dan 'Complain' karena memiliki kurang dari 5 kategori dan tidak ada tingkatan dalam kategori.
#
# Membuat transformer encoding sesuai dengan penjabaran diatas.

# %%
# Skema transformer dengan scaling

scaler = Pipeline([
    ('Missing Value', IterativeImputer(max_iter=10)),
    ('Scaler', RobustScaler())
])

transformer1 = ColumnTransformer([
    ('OHE', OneHotEncoder(drop='first'),['PreferredLoginDevice', 'PreferredPaymentMode', 'Gender', 'PreferedOrderCat', 'MaritalStatus', 'Complain']),
    ('Scaler', scaler, ['Tenure', 'WarehouseToHome', 'HourSpendOnApp', 'NumberOfDeviceRegistered', 'SatisfactionScore', 'NumberOfAddress', 'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount', 'DaySinceLastOrder', 'CashbackAmount'])
], remainder='passthrough')

transformer1
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('OHE', OneHotEncoder(drop='first'),
#                                  ['PreferredLoginDevice',
#                                   'PreferredPaymentMode', 'Gender',
#                                   'PreferedOrderCat', 'MaritalStatus',
#                                   'Complain']),
#                                 ('Scaler',
#                                  Pipeline(steps=[('Missing Value',
#                                                   IterativeImputer()),
#                                                  ('Scaler', RobustScaler())]),
#                                  ['Tenure', 'WarehouseToHome', 'HourSpendOnApp',
#                                   'NumberOfDeviceRegistered',
#                                   'SatisfactionScore', 'NumberOfAddress',
#                                   'OrderAmountHikeFromlastYear', 'CouponUsed',
# ...

# %%
# Skema transformer tanpa scaling

# Menginisialisasi IterativeImputer
imputer = IterativeImputer(max_iter=10)

transformer2 = ColumnTransformer([
    ('OHE', OneHotEncoder(drop='first'),['PreferredLoginDevice', 'PreferredPaymentMode', 'Gender', 'PreferedOrderCat', 'MaritalStatus', 'Complain']),
    ('Missing Value', imputer,['Tenure', 'WarehouseToHome', 'HourSpendOnApp', 'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount', 'DaySinceLastOrder', 'CashbackAmount'])
], remainder='passthrough')

transformer2
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('OHE', OneHotEncoder(drop='first'),
#                                  ['PreferredLoginDevice',
#                                   'PreferredPaymentMode', 'Gender',
#                                   'PreferedOrderCat', 'MaritalStatus',
#                                   'Complain']),
#                                 ('Missing Value', IterativeImputer(),
#                                  ['Tenure', 'WarehouseToHome', 'HourSpendOnApp',
#                                   'OrderAmountHikeFromlastYear', 'CouponUsed',
#                                   'OrderCount', 'DaySinceLastOrder',
#                                   'CashbackAmount'])])

# %% [markdown]
# ## **Model Benchmarking**
# ---

# %% [markdown]
# Terdapat beberapa metode klasifikasi yang akan diuji coba sebagai penentuan model terbaik untuk dataset ini, diantaranya ialah Logistic Regression, KNearest Neighbour, Decision Tree, Random Forest, XGBoost, Voting, dan Stacking.

# %% [markdown]
# Beberapa hal yang perlu dilakukan dalam model benchmarking adalah:
# - Dilakukan resampling karena terdapat imbalance data berdasarkan hasil data analisis. Metode resampling yang digunakan adalah RandomOverSampler untuk meningkatkan kelas minoritas mengikuti kelas mayoritas, serta RandomUnderSampling dan Near Miss yang berfungsi menurunkan kelas mayoritas mengikuti kelas minoritas.
# - Scaler yang digunakan adalah Robust Scaler, karena scaler ini tidak sensitif terhadap outlier.
# - Metrik yang digunakan adalah F2 Score. F2 Score lebih baik digunakan karena fokus pada menghindari False Negatives, yang penting dalam mengidentifikasi pelanggan yang berpotensi *churn*.
# - Dilakukan 4 kondisi benchmarking model untuk mengetahui model yang terbaik, yaitu:
#     1. Modeling Menggunakan Pipeline Dengan Kondisi Scaling dan Resampling
#     2. Modeling Menggunakan Pipeline Dengan Kondisi Scaling Tetapi Tidak Resampling
#     3. Modeling Menggunakan Pipeline Dengan Kondisi Tidak Scaling Tetapi Resampling
#     4. Modeling Menggunakan Pipeline Dengan Kondisi Tidak Scaling dan Tidak Resampling

# %% [markdown]
# #### **1. Modeling Menggunakan Pipeline Dengan Kondisi Scaling dan Resampling**

# %%
# Skema 1 : Modeling dengan Encoding, Scaling, dan Resampling

#Algoritma model yang digunakan
logreg = LogisticRegression(random_state=2023)
dt = DecisionTreeClassifier(random_state=2023)
knn = KNeighborsClassifier()
svm = SVC(random_state=2023)
xgb = XGBClassifier()
rf = RandomForestClassifier(random_state=2023)

vc_hard = VotingClassifier(estimators=[
    ('model1', logreg),
    ('model2', dt),
    ('model3', knn),
    ('model4', svm),
    ('model5', xgb),
    ('model6', rf),
],voting='hard')

sc_logreg = StackingClassifier(estimators=[
    ('model1', logreg),
    ('model2', dt),
    ('model3', knn),
    ('model4', svm),
    ('model5', xgb),
    ('model6', rf),
],final_estimator=LogisticRegression(random_state=2023))

sc_dt = StackingClassifier(estimators=[
    ('model1', logreg),
    ('model2', dt),
    ('model3', knn),
    ('model4', svm),
    ('model5', xgb),
    ('model6', rf),
],final_estimator=DecisionTreeClassifier(random_state=2023))

sc_knn = StackingClassifier(estimators=[
    ('model1', logreg),
    ('model2', dt),
    ('model3', knn),
    ('model4', svm),
    ('model5', xgb),
    ('model6', rf),
],final_estimator=KNeighborsClassifier())

sc_svm = StackingClassifier(estimators=[
    ('model1', logreg),
    ('model2', dt),
    ('model3', knn),
    ('model4', svm),
    ('model5', xgb),
    ('model6', rf),
],final_estimator=SVC(random_state=2023))

# Metode resampling yang digunakan
ros = RandomOverSampler()
nm = NearMiss()
rus = RandomUnderSampler()

model = [logreg,dt,knn,svm,xgb,rf,vc_hard,sc_logreg,sc_dt,sc_knn,sc_svm] # list algoritma model yang dipakai
resampling = [ros,nm,rus] # list metode resampling yang digunakan
f2_score = [] # list kosong untuk menampung hasil f2 score
std = [] # list kosong untuk menampung hasil standar deviasi

# Menampilkan Looping setiap model dengan resampling menggunakan skema transformer1
for i in model :
    for j in resampling :
        model_pipe = Pipeline([
            ('Preprocess',transformer1),
            ('imba',j),
            ('clf',i)
        ])
        pipe_cv = cross_val_score(model_pipe, xtrain, ytrain, cv=5, scoring=make_scorer(fbeta_score, beta=2)) #cross validation
        f2_score.append(pipe_cv.mean()) #rata-rata f2 score dari cross validation
        std.append(pipe_cv.std()) #nilai standar deviasi dari cross validation

# Memasukkan hasil modeling sesuai dengan urutan f2 score terbesar kedalam data frame
pd.DataFrame({
    'Model' : ['Logistic Regression ROS','Logistic Regression Near Miss','Logistic Regression RUS',
               'DT ROS','DT Near Miss','DT RUS',
               'KNN ROS','KNN Near Miss','KNN RUS',
               'SVM ROS','SVM Near Miss','SVM RUS',
               'XGBoost ROS','XGBoost Near Miss','XGBoost RUS',
               'Random Forest ROS','Random Forest Near Miss','Random Forest RUS',
               'Hard Voting ROS','Hard Voting Near Miss','Hard Voting RUS',
               'Stacking Classifier Logreg ROS','Stacking Classifier Logreg Near Miss','Stacking Classifier Logreg RUS',
               'Stacking Classifier DT ROS','Stacking Classifier DT Near Miss','Stacking Classifier DT RUS',
               'Stacking Classifier KNN ROS','Stacking Classifier KNN Near Miss','Stacking Classifier KNN RUS',
               'Stacking Classifier SVM ROS','Stacking Classifier SVM Near Miss','Stacking Classifier SVM RUS',
               ],
    'F2 Score Mean' : f2_score,
    'F2 Score Std' : std
}).sort_values('F2 Score Mean', ascending=False)
# Out:
#                                    Model  F2 Score Mean  F2 Score Std
# 12                           XGBoost ROS       0.876336      0.022659
# 15                     Random Forest ROS       0.861839      0.015586
# 32           Stacking Classifier SVM RUS       0.852214      0.017304
# 23        Stacking Classifier Logreg RUS       0.839935      0.017672
# 14                           XGBoost RUS       0.831869      0.020286
# 17                     Random Forest RUS       0.829639      0.020420
# 31     Stacking Classifier SVM Near Miss       0.828496      0.021489
# 29           Stacking Classifier KNN RUS       0.826641      0.020622
# 22  Stacking Classifier Logreg Near Miss       0.824826      0.016530
# 13                     XGBoost Near Miss       0.822602      0.010263
# 16               Random Forest Near Miss       0.800291      0.012761
# 19                 Hard Voting Near Miss       0.798377      0.020437
# ...

# %% [markdown]
# #### **2. Modeling Menggunakan Pipeline Dengan Kondisi Scaling Tetapi Tidak Resampling**

# %%
# Skema 2 : Modeling dengan Encoding dan Scaling

#Algoritma model yang digunakan
logreg = LogisticRegression(random_state=2023)
dt = DecisionTreeClassifier(random_state=2023)
knn = KNeighborsClassifier()
svm = SVC(random_state=2023)
xgb = XGBClassifier()
rf = RandomForestClassifier(random_state=2023)

vc_hard = VotingClassifier(estimators=[
    ('model1', logreg),
    ('model2', dt),
    ('model3', knn),
    ('model4', svm),
    ('model5', xgb),
    ('model6', rf),
],voting='hard')

sc_logreg = StackingClassifier(estimators=[
    ('model1', logreg),
    ('model2', dt),
    ('model3', knn),
    ('model4', svm),
    ('model5', xgb),
    ('model6', rf),
],final_estimator=LogisticRegression(random_state=2023))

sc_dt = StackingClassifier(estimators=[
    ('model1', logreg),
    ('model2', dt),
    ('model3', knn),
    ('model4', svm),
    ('model5', xgb),
    ('model6', rf),
],final_estimator=DecisionTreeClassifier(random_state=2023))

sc_knn = StackingClassifier(estimators=[
    ('model1', logreg),
    ('model2', dt),
    ('model3', knn),
    ('model4', svm),
    ('model5', xgb),
    ('model6', rf),
],final_estimator=KNeighborsClassifier())

sc_svm = StackingClassifier(estimators=[
    ('model1', logreg),
    ('model2', dt),
    ('model3', knn),
    ('model4', svm),
    ('model5', xgb),
    ('model6', rf),
],final_estimator=SVC(random_state=2023))

model = [logreg,dt,knn,svm,xgb,rf,vc_hard,sc_logreg,sc_dt,sc_knn,sc_svm] # list algoritma model yang dipakai
f2_score = [] # list kosong untuk menampung hasil f2 score
std = [] # list kosong untuk menampung hasil standar deviasi

# Menampilkan Looping setiap model dengan resampling menggunakan skema transformer1
for i in model :
    model_pipe = Pipeline([
        ('Preprocess',transformer1),
        ('imba',j),
        ('clf',i)
    ])
    pipe_cv = cross_val_score(model_pipe, xtrain, ytrain, cv=5, scoring=make_scorer(fbeta_score, beta=2)) #cross validation
    f2_score.append(pipe_cv.mean()) #rata-rata f2 score dari cross validation
    std.append(pipe_cv.std()) #nilai standar deviasi dari cross validation

# Memasukkan hasil modeling sesuai dengan urutan f2 score terbesar kedalam data frame
pd.DataFrame({
    'Model' : ['Logistic Regression',
               'DT',
               'KNN',
               'SVM',
               'XGBoost',
               'Random Forest',
               'Hard Voting',
               'Stacking Classifier Logreg',
               'Stacking Classifier DT',
               'Stacking Classifier KNN',
               'Stacking Classifier SVM'
               ],
    'F2 Score Mean' : f2_score,
    'F2 Score Std' : std
}).sort_values('F2 Score Mean', ascending=False)
# Out:
#                          Model  F2 Score Mean  F2 Score Std
# 7   Stacking Classifier Logreg       0.841420      0.011167
# 10     Stacking Classifier SVM       0.836354      0.024555
# 4                      XGBoost       0.833828      0.023947
# 9      Stacking Classifier KNN       0.819899      0.025565
# 5                Random Forest       0.818255      0.026603
# 6                  Hard Voting       0.761618      0.099794
# 1                           DT       0.755895      0.025681
# 8       Stacking Classifier DT       0.748762      0.025600
# 0          Logistic Regression       0.476613      0.243427
# 3                          SVM       0.347822      0.037642
# 2                          KNN       0.341529      0.018913

# %% [markdown]
# #### **3. Modeling Menggunakan Pipeline Dengan Kondisi Tidak Scaling Tetapi Resampling**

# %%
# Skema 3 : Modeling dengan Encoding dan Resampling

#Algoritma model yang digunakan
logreg = LogisticRegression(random_state=2023)
dt = DecisionTreeClassifier(random_state=2023)
knn = KNeighborsClassifier()
svm = SVC(random_state=2023)
xgb = XGBClassifier()
rf = RandomForestClassifier(random_state=2023)

vc_hard = VotingClassifier(estimators=[
    ('model1', logreg),
    ('model2', dt),
    ('model3', knn),
    ('model4', svm),
    ('model5', xgb),
    ('model6', rf),
],voting='hard')

sc_logreg = StackingClassifier(estimators=[
    ('model1', logreg),
    ('model2', dt),
    ('model3', knn),
    ('model4', svm),
    ('model5', xgb),
    ('model6', rf),
],final_estimator=LogisticRegression(random_state=2023))

sc_dt = StackingClassifier(estimators=[
    ('model1', logreg),
    ('model2', dt),
    ('model3', knn),
    ('model4', svm),
    ('model5', xgb),
    ('model6', rf),
],final_estimator=DecisionTreeClassifier(random_state=2023))

sc_knn = StackingClassifier(estimators=[
    ('model1', logreg),
    ('model2', dt),
    ('model3', knn),
    ('model4', svm),
    ('model5', xgb),
    ('model6', rf),
],final_estimator=KNeighborsClassifier())

sc_svm = StackingClassifier(estimators=[
    ('model1', logreg),
    ('model2', dt),
    ('model3', knn),
    ('model4', svm),
    ('model5', xgb),
    ('model6', rf),
],final_estimator=SVC(random_state=2023))

# Metode resampling yang digunakan
ros = RandomOverSampler()
nm = NearMiss()
rus = RandomUnderSampler()

model = [logreg,dt,knn,svm,xgb,rf,vc_hard,sc_logreg,sc_dt,sc_knn,sc_svm] # list algoritma model yang dipakai
resampling = [ros,nm,rus] # list metode resampling yang digunakan
f2_score = [] # list kosong untuk menampung hasil f2 score
std = [] # list kosong untuk menampung hasil standar deviasi

# Menampilkan Looping setiap model dengan resampling menggunakan skema transformer1
for i in model :
    for j in resampling :
        model_pipe = Pipeline([
            ('Preprocess',transformer2),
            ('imba',j),
            ('clf',i)
        ])
        pipe_cv = cross_val_score(model_pipe, xtrain, ytrain, cv=5, scoring=make_scorer(fbeta_score, beta=2)) #cross validation
        f2_score.append(pipe_cv.mean()) #rata-rata f2 score dari cross validation
        std.append(pipe_cv.std()) #nilai standar deviasi dari cross validation

# Memasukkan hasil modeling sesuai dengan urutan f2 score terbesar kedalam data frame
pd.DataFrame({
    'Model' : ['Logistic Regression ROS','Logistic Regression Near Miss','Logistic Regression RUS',
               'DT ROS','DT Near Miss','DT RUS',
               'KNN ROS','KNN Near Miss','KNN RUS',
               'SVM ROS','SVM Near Miss','SVM RUS',
               'XGBoost ROS','XGBoost Near Miss','XGBoost RUS',
               'Random Forest ROS','Random Forest Near Miss','Random Forest RUS',
               'Hard Voting ROS','Hard Voting Near Miss','Hard Voting RUS',
               'Stacking Classifier Logreg ROS','Stacking Classifier Logreg Near Miss','Stacking Classifier Logreg RUS',
               'Stacking Classifier DT ROS','Stacking Classifier DT Near Miss','Stacking Classifier DT RUS',
               'Stacking Classifier KNN ROS','Stacking Classifier KNN Near Miss','Stacking Classifier KNN RUS',
               'Stacking Classifier SVM ROS','Stacking Classifier SVM Near Miss','Stacking Classifier SVM RUS',
               ],
    'F2 Score Mean' : f2_score,
    'F2 Score Std' : std
}).sort_values('F2 Score Mean', ascending=False)
# Out:
#                                    Model  F2 Score Mean  F2 Score Std
# 12                           XGBoost ROS       0.879117      0.032041
# 15                     Random Forest ROS       0.847494      0.027152
# 14                           XGBoost RUS       0.842206      0.022328
# 29           Stacking Classifier KNN RUS       0.836589      0.018247
# 32           Stacking Classifier SVM RUS       0.836391      0.029148
# 23        Stacking Classifier Logreg RUS       0.833529      0.014987
# 17                     Random Forest RUS       0.827743      0.024902
# 18                       Hard Voting ROS       0.799548      0.042179
# 20                       Hard Voting RUS       0.785164      0.017922
# 3                                 DT ROS       0.779073      0.017554
# 21        Stacking Classifier Logreg ROS       0.758047      0.024969
# 5                                 DT RUS       0.757566      0.011409
# ...

# %% [markdown]
# #### **4. Modeling Menggunakan Pipeline Dengan Kondisi Tidak Scaling dan Tidak Resampling**

# %%
# Skema 4 : Modeling dengan Encoding

#Algoritma model yang digunakan
logreg = LogisticRegression(random_state=2023)
dt = DecisionTreeClassifier(random_state=2023)
knn = KNeighborsClassifier()
svm = SVC(random_state=2023)
xgb = XGBClassifier()
rf = RandomForestClassifier(random_state=2023)

vc_hard = VotingClassifier(estimators=[
    ('model1', logreg),
    ('model2', dt),
    ('model3', knn),
    ('model4', svm),
    ('model5', xgb),
    ('model6', rf),
],voting='hard')

sc_logreg = StackingClassifier(estimators=[
    ('model1', logreg),
    ('model2', dt),
    ('model3', knn),
    ('model4', svm),
    ('model5', xgb),
    ('model6', rf),
],final_estimator=LogisticRegression(random_state=2023))

sc_dt = StackingClassifier(estimators=[
    ('model1', logreg),
    ('model2', dt),
    ('model3', knn),
    ('model4', svm),
    ('model5', xgb),
    ('model6', rf),
],final_estimator=DecisionTreeClassifier(random_state=2023))

sc_knn = StackingClassifier(estimators=[
    ('model1', logreg),
    ('model2', dt),
    ('model3', knn),
    ('model4', svm),
    ('model5', xgb),
    ('model6', rf),
],final_estimator=KNeighborsClassifier())

sc_svm = StackingClassifier(estimators=[
    ('model1', logreg),
    ('model2', dt),
    ('model3', knn),
    ('model4', svm),
    ('model5', xgb),
    ('model6', rf),
],final_estimator=SVC(random_state=2023))

model = [logreg,dt,knn,svm,xgb,rf,vc_hard,sc_logreg,sc_dt,sc_knn,sc_svm] # list algoritma model yang dipakai
f2_score = [] # list kosong untuk menampung hasil f2 score
std = [] # list kosong untuk menampung hasil standar deviasi

# Menampilkan Looping setiap model dengan resampling menggunakan skema transformer1
for i in model :
    model_pipe = Pipeline([
        ('Preprocess',transformer2),
        ('imba',j),
        ('clf',i)
    ])
    pipe_cv = cross_val_score(model_pipe, xtrain, ytrain, cv=5, scoring=make_scorer(fbeta_score, beta=2)) #cross validation
    f2_score.append(pipe_cv.mean()) #rata-rata f2 score dari cross validation
    std.append(pipe_cv.std()) #nilai standar deviasi dari cross validation

# Memasukkan hasil modeling sesuai dengan urutan f2 score terbesar kedalam data frame
pd.DataFrame({
    'Model' : ['Logistic Regression',
               'DT',
               'KNN',
               'SVM',
               'XGBoost',
               'Random Forest',
               'Hard Voting',
               'Stacking Classifier Logreg',
               'Stacking Classifier DT',
               'Stacking Classifier KNN',
               'Stacking Classifier SVM'
               ],
    'F2 Score Mean' : f2_score,
    'F2 Score Std' : std
}).sort_values('F2 Score Mean', ascending=False)
# Out:
#                          Model  F2 Score Mean  F2 Score Std
# 10     Stacking Classifier SVM       0.840173      0.023213
# 7   Stacking Classifier Logreg       0.835674      0.017504
# 4                      XGBoost       0.830274      0.020117
# 9      Stacking Classifier KNN       0.828185      0.022275
# 5                Random Forest       0.822348      0.022228
# 6                  Hard Voting       0.792622      0.029450
# 8       Stacking Classifier DT       0.756228      0.025520
# 1                           DT       0.751976      0.031947
# 0          Logistic Regression       0.649423      0.030560
# 2                          KNN       0.424371      0.018256
# 3                          SVM       0.348916      0.037228

# %% [markdown]
# Berdasarkan hasil fitting ke data train menggunakan cross validation diperoleh 3 model teratas dengan nilai F2 Score tertinggi, yaitu:
#
#
# | Nomor Model | Nama Model           | Scaling        | Resampling           | F2 Score   |
# |-------------|----------------------|----------------|----------------------|------------|
# | Model 1     | XGBoost              | Scaling  | Random Over Sampling | 0.876  |
# | Model 2     | XGBoost              | Tidak Scaling         | Random Over Sampling | 0.879   |
# | Model 3     | Random Forest | Scaling  | Random Over Sampling| 0.861  |

# %% [markdown]
# #### **Pengujian 3 Model Terbaik**

# %%
# Testing model 1 : XGBoost dengan kondisi scaling dan resampling metode Random Over Sampling

best_model1 = Pipeline([
    ('Preprocess',transformer1),
    ('imba',ros),
    ('clf',xgb)
])

best_model1.fit(xtrain, ytrain)
pred = best_model1.predict(xtest)
f2_model1 = fbeta_score(ytest, pred, beta=2)

f2_model1
# Out:
# 0.8922914466737064

# %%
# Testing model 2 : XGBoost dengan kondisi tidak scaling tetapi resampling metode Random Over Sampling

best_model2 = Pipeline([
    ('Preprocess',transformer2),
    ('imba',ros),
    ('clf',xgb)
])

best_model2.fit(xtrain, ytrain)
pred = best_model2.predict(xtest)
f2_model2 = fbeta_score(ytest, pred, beta=2)

f2_model2
# Out:
# 0.9177215189873418

# %%
# Testing model 3 : Random Forest dengan kondisi scaling dan resampling

best_model3 = Pipeline([
    ('Preprocess',transformer1),
    ('imba',ros),
    ('clf',rf)
])

best_model3.fit(xtrain, ytrain)
pred = best_model3.predict(xtest)
f2_model3 = fbeta_score(ytest, pred, beta=2)

f2_model3
# Out:
# 0.9042553191489363

# %% [markdown]
# Bila dilihat pada hasil pengujian data train dengan data test terhadap 3 model terbaik, pipeline yang diberi perlakuan resampling adalah model yang tepat untuk dilanjutkan *tuning*.
#
# Selanjutnya dilakukan tuning pada model 1, 2, dan 3.

# %% [markdown]
# ## **Hyperparameter Tuning**
# ---

# %% [markdown]
# Bila dilihat pada hasil pengujian data train dengan data test terhadap 3 model terbaik, semuanya tidak menunjukkan hasil yang overfitting yaitu adanya perbedaan yang signifikan antara data train dan data test. Oleh karenanya, ketiga model tersebut dapat dilanjutkan ke proses tuning.
#
# Sebagai usaha untuk menaikan kebaikkan model maka dilakukan hyperparameter tuning kepada 3 model yang telah di testing sebelumnya

# %% [markdown]
# #### **Model 1**

# %%
# Hyperparameter tuning untuk model 2

space = {
    'clf__stack_method': ['auto', 'predict_proba'],
    'clf__n_estimators': [50, 100],
    'clf__max_depth': [5, 10],
    'clf__min_samples_split': [2, 5],
    'clf__min_samples_leaf': [1, 2,],

}

# Membuat objek GridSearchCV
grid_search1 = GridSearchCV(
    best_model1,
    param_grid=space,
    cv=5,
    scoring=make_scorer(fbeta_score, beta=2),
    n_jobs=-1
)

# Melakukan penyetelan pada data latih
grid_search1.fit(xtrain, ytrain)

# Mendapatkan model terbaik setelah penyetelan
best_model_after_tuning1 = grid_search1.best_estimator_

# Menampilkan parameter terbaik
print("Best hyperparameters:")
print(grid_search1.best_params_)

# Melakukan prediksi dengan model terbaik setelah penyetelan
pred_after_tuning1 = best_model_after_tuning1.predict(xtest)

# Menghitung skor f2 setelah penyetelan
f2_after_tuning1 = fbeta_score(ytest, pred_after_tuning1, beta=2)

# Menampilkan hasil penyetelan
print("F2 Score after tuning:", f2_after_tuning1)
# Out:
# Best hyperparameters:
# {'clf__max_depth': 10, 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 2, 'clf__n_estimators': 100, 'clf__stack_method': 'predict_proba'}
# F2 Score after tuning: 0.9191176470588235

# %%
# Menerapkan kombinasi terbaik untuk prediksi

pred_tuned1 = grid_search1.best_estimator_.predict(xtest)
f2_tuned1 = fbeta_score(ytest,pred_tuned1,beta=2)
f2_tuned1
# Out:
# 0.9191176470588235

# %% [markdown]
# #### **Model 2**

# %%
# Hyperparameter tuning untuk model 2

space = {
    'clf__stack_method': ['auto', 'predict_proba'],
    'clf__n_estimators': [50, 100],
    'clf__max_depth': [5, 10],
    'clf__min_samples_split': [2, 5],
    'clf__min_samples_leaf': [1, 2,],

}

# Membuat objek GridSearchCV
grid_search2 = GridSearchCV(
    best_model2,
    param_grid=space,
    cv=5,
    scoring=make_scorer(fbeta_score, beta=2),
    n_jobs=-1
)

# Melakukan penyetelan pada data latih
grid_search2.fit(xtrain, ytrain)

# Mendapatkan model terbaik setelah penyetelan
best_model_after_tuning2 = grid_search2.best_estimator_

# Menampilkan parameter terbaik
print("Best hyperparameters:")
print(grid_search2.best_params_)

# Melakukan prediksi dengan model terbaik setelah penyetelan
pred_after_tuning2 = best_model_after_tuning2.predict(xtest)

# Menghitung skor f2 setelah penyetelan
f2_after_tuning2 = fbeta_score(ytest, pred_after_tuning2, beta=2)

# Menampilkan hasil penyetelan
print("F2 Score after tuning:", f2_after_tuning2)
# Out:
# Best hyperparameters:
# {'clf__max_depth': 10, 'clf__min_samples_leaf': 2, 'clf__min_samples_split': 2, 'clf__n_estimators': 100, 'clf__stack_method': 'auto'}
# F2 Score after tuning: 0.9224318658280922

# %%
# Menerapkan kombinasi terbaik untuk prediksi

pred_tuned2 = grid_search2.best_estimator_.predict(xtest)
f2_tuned2 = fbeta_score(ytest,pred_tuned2,beta=2)
f2_tuned2
# Out:
# 0.9224318658280922

# %% [markdown]
# #### **Model 3**

# %%
# Menentukan ruang pencarian hyperparameter untuk setiap komponen di dalam pipeline
param_grid = {
    'clf__n_estimators': [50, 100],
    'clf__max_depth': [5, 10],
    'clf__min_samples_split': [2, 5],
    'clf__min_samples_leaf': [1, 2],
    'clf__criterion': ['gini', 'entropy'],
    'clf__max_features': ['auto', 'sqrt']

}
grid_search3 = GridSearchCV(
    estimator=best_model3,
    param_grid=param_grid,
    scoring=make_scorer(fbeta_score, beta=2),
    cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=42))

# Melakukan penyetelan pada data latih
grid_search3.fit(xtrain, ytrain)

# Mendapatkan model terbaik setelah penyetelan
best_model_after_tuning = grid_search3.best_estimator_

# Melakukan prediksi dengan model terbaik setelah penyetelan
pred_after_tuning = best_model_after_tuning.predict(xtest)

# Menghitung skor f2 setelah penyetelan
f2_after_tuning = fbeta_score(ytest, pred_after_tuning, beta=2)

# Menampilkan hasil penyetelan
print("Best hyperparameters:", grid_search3.best_params_)
print("F2 Score after tuning:", f2_after_tuning)
# Out:
# Best hyperparameters: {'clf__criterion': 'entropy', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 5, 'clf__n_estimators': 100}
# F2 Score after tuning: 0.8376690946930281

# %%
# Menerapkan kombinasi terbaik untuk prediksi

pred_tuned3 = grid_search3.best_estimator_.predict(xtest)
f2_tuned3 = fbeta_score(ytest,pred_tuned3,beta=2)
f2_tuned3
# Out:
# 0.8376690946930281

# %% [markdown]
# #### **Rekapitulasi F2 Score Sebelum Tuning dan Setelah Tuning**

# %%
# Membuat DataFrame hasil rekapitulasi f2 score sebelum tuning dan setelah tuning

recap = pd.DataFrame({
    'Nomor Model' : ['Model 1','Model 2','Model 3'],
    'Nama Model' : ['XGBoost','XGBoost','Random Forest'],
    'Scaling' : ['Scaling','Tanpa Scaling','Scaling'],
    'Resampling' : ['Random Over Sampling','Random Over Sampling','Random Over Sampling'],
    'F2 Score Sebelum Tuning' : [f2_model1,f2_model2,f2_model3],
    'F2 Score Setelah Tuning' : [f2_tuned1,f2_tuned2,f2_tuned3]
})

recap
# Out:
#   Nomor Model     Nama Model        Scaling            Resampling  \
# 0     Model 1        XGBoost        Scaling  Random Over Sampling
# 1     Model 2        XGBoost  Tanpa Scaling  Random Over Sampling
# 2     Model 3  Random Forest        Scaling  Random Over Sampling
#
#    F2 Score Sebelum Tuning  F2 Score Setelah Tuning
# 0                 0.892291                 0.919118
# 1                 0.917722                 0.922432
# 2                 0.904255                 0.837669

# %% [markdown]
# Setelah dilakukan hyperparameter tuning, performa yang dihasilkan model pertama dan kedua mengalami kenaikan setelah tuning,dan model ke 2 mendapatkan nilai F2 terbaik, sedangkan model ketiga mengalami penurunan. Dari ketiga model yang dituning, model **XGBoost** dengan parameter {'clf__max_depth': 10, 'clf__min_samples_leaf': 2, 'clf__min_samples_split': 2, 'clf__n_estimators': 100, 'clf__stack_method': 'auto'} dengan kondisi dilakukan encoding, tanpa scaling, dan resampling dengan metode Random Over Sampling memilki performa terbaik sebesar 92,2% berdasarkan nilai f2 scorenya.
#
# XGBoost, singkatan dari "Extreme Gradient Boosting", adalah algoritma *machine learning* yang dapat digunakan untuk data klasifiksai dan regresi karena keefisienannya dalam analisis bisnis. Algoritma ini memanfaatkan pendekatan ensemble, yang artinya membangun banyak model keputusan dan kemudian menggabungkannya untuk meningkatkan performa prediksi. XGBoost menggabungkan pohon keputusan dengan pendekatan penguatan gradien. Pada setiap langkah, algoritma mencoba memperbaiki kesalahan dari langkah sebelumnya. Dengan cara ini, model secara berurutan memperbaiki dirinya sendiri sehingga meminimalkan kesalahan dengan memanfaatkan gradien dari fungsi kerugian yang dipilih.
#
# Keunggulan dari XGBoost adalah memiliki teknik regularisasi yang memungkinkannya untuk mencegah overfitting, bahkan ketika dataset yang dimiliki relatif kecil. Optimisasi yang dioptimalkan untuk kecepatan dan efisiensi kinerja, serta kemampuan untuk mengidentifikasi fitur penting yang paling mempengaruhi hasil prediksi.

# %% [markdown]
# ### **Simpan Model Final dengan Parameter terbaik**

# %% [markdown]
# Pada tahap ini kita akan simpan Model dengan parameter terbaik nya menggunakan pickle

# %%
# Simpan Model
import pickle

# Inisialisasi model XGBClassifier dengan parameter yang diinginkan
xgb_params = {
    'max_depth': 10,
    'min_samples_leaf': 2,
    'min_samples_split': 2,
    'n_estimators': 100,
    'stack_method': 'auto'
}

xgb = XGBClassifier(**xgb_params)

# Definisikan pipeline Anda dengan transformer1, ros, dan xgb
best_model_final = Pipeline([
    ('Preprocess', transformer2),
    ('imba', RandomOverSampler()),
    ('clf', xgb)
])

best_model_final.fit(xtrain, ytrain)

pickle.dump(best_model_final, open('Final_Model_E-Commerce_Customer_Churn.sav', 'wb'))

nama_file = 'Final_Model_E-Commerce_Customer_Churn.sav'
load_model = pickle.load(open(nama_file, 'rb'))
load_model
# Out:
# Pipeline(steps=[('Preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('OHE',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['PreferredLoginDevice',
#                                                    'PreferredPaymentMode',
#                                                    'Gender', 'PreferedOrderCat',
#                                                    'MaritalStatus',
#                                                    'Complain']),
#                                                  ('Missing Value',
#                                                   IterativeImputer(),
#                                                   ['Tenure', 'WarehouseToHome',
#                                                    'HourSpendOnApp',
#                                                    'OrderAmountHikeFromlastYear',
# ...

# %% [markdown]
# ## **Feature Importance & SHAP**
# ---

# %% [markdown]
# Untuk memperoleh pemahaman tentang fitur-fitur yang memiliki pengaruh paling signifikan pada suatu model, dilakukan plotting nilai SHAP untuk setiap fitur pada setiap sampel data. Grafik di bawah ini mengurutkan fitur-fitur berdasarkan total nilai SHAP mereka pada seluruh sampel, dan menggunakan nilai SHAP untuk menunjukkan distribusi dampak masing-masing fitur terhadap hasil output model. Warna pada grafik mencerminkan nilai fitur, di mana warna merah menunjukkan nilai tinggi dan warna biru menunjukkan nilai rendah.

# %%
# Training model
best_model_final.fit(xtrain, ytrain)

# Mendefinisikan model yang telah dilatih
model_with_shap = best_model_final.named_steps['clf']

# Memilih subset data untuk analisis SHAP
X_shap = best_model_final.named_steps['Preprocess'].transform(xtest)

# Mendapatkan nama fitur setelah preprocessing
feature_names = best_model_final.named_steps['Preprocess'].get_feature_names_out()

# Mengonversi X_shap ke DataFrame
X_shap_df = pd.DataFrame(X_shap, columns=feature_names)

# Mendapatkan objek explainer dari model
explainer = shap.TreeExplainer(model_with_shap)

# Menghitung nilai SHAP untuk subset data
shap_values = explainer.shap_values(X_shap)

# Menampilkan summary plot SHAP
shap.summary_plot(shap_values, X_shap_df, show=False)  # show=False agar tidak tampil dua kali plot
plt.title('Summary Plot SHAP - Feature Importances')
plt.show()

# %% [markdown]
# Berdasarkan grafik, dapat disimpulkan bahwa fitur yang paling berpengaruh terhadap prediksi *churn* adalah *tenure* (durasi berlangganan), yang menempati peringkat paling atas dalam tingkat pentingnya fitur. Dapat dilihat bahwa semakin singkat durasi belangganan pelanggan, maka potensi churn semakin meningkat. Hal ini dapat dilihat pada analisis pengaruh tenure terhadap *churn*, perusahaan tidak bisa mempertahankan pelanggan di fase-fase awal berlangganan. Selanjutnya fitur yang paling berpengaruh juga ialah *complain*. Semakin banyak keluhan yang diperoleh, maka potensi churn semakin meningkat. Peringkat ketiga yaitu *number of address*, dimana semakin banyak jumlah alamat yang terdaftar dalam e-commerce, maka potensi churn juga semakin meningkat.
#
# Hasil ini memberikan wawasan berharga kepada perusahaan untuk memfokuskan strategi retensi pelanggan mereka pada elemen-elemen ini.

# %% [markdown]
# ## **Kesimpulan**
# ---

# %% [markdown]
# ### **Kesimpulan Model**

# %%
best_model_final.fit(xtrain, ytrain)
pred_model_final = best_model_final.predict(xtest)
f2_model_final = fbeta_score(ytest, pred_model_final, beta=2)

# Menampilkan classification report hasil prediksi menggunakan model final
print(classification_report(ytest,pred_model_final))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       936
#            1       0.92      0.93      0.93       190
#
#     accuracy                           0.98      1126
#    macro avg       0.95      0.96      0.96      1126
# weighted avg       0.98      0.98      0.98      1126

# %% [markdown]
# Berdasarkan hasil diatas dapat disimpulkan bahwa dengan prediksi menggunakan model yang sudah dibuat, model dapat mengetahui 98% pelanggan yang tidak churn dan 93% pelanggan yang churn berdasarkan recall. Selain itu model memiliki kemampuan untuk mengidentifikasi 93% pelanggan yang sebenarnya *churn* (recall), dan 92% dari pelanggan yang diprediksi *churn* oleh model yang benar-benar akan *churn* (precission).
#
# Bila dilihat pada hasil pengujian data train dengan data test terhadap model terbaik, model tidak menunjukkan hasil yang overfitting yaitu adanya perbedaan yang signifikan antara data train dan data test. Oleh karenanya, model ini dapat di percaya **(Akurat)**
#
# Jika nilai F2 Score nya ada perbedaan yang signifikan maka harus kita evaluasi Kembali karena model ini terindikasi overfitting dan belom dapat di percaya **(Tidak Akurat)**

# %% [markdown]
# ### **Mempriotaskan Customer yang akan Churn Menggunakan Predict Proba**

# %% [markdown]
# Pada tahap ini kita akan menggunakan Predict Proba untuk melihat customer mana yang memiliki probabilitas churn tertinggi.

# %%
predicted_proba = best_model_final.predict_proba(xtest)

prob_churn = predicted_proba[:, 1]

# Mengambil index dari 10 pelanggan dengan probabilitas churn tertinggi
top_10_indices = np.argsort(prob_churn)[::-1][:10]

# Mendapatkan customer ID dari pelanggan top 10
top_10_customer_ids = data.iloc[top_10_indices]['CustomerID']

# Mendapatkan probabilitas churn untuk 10 pelanggan teratas
top_10_prob_churn = predicted_proba[top_10_indices]

# Membuat DataFrame untuk menampilkan CustomerID dan probabilitas churn
top_10_customers_df = pd.DataFrame({
    'CustomerID': data.iloc[top_10_indices]['CustomerID'],
    'Probabilitas Churn': top_10_prob_churn[:, 1]  # Mengambil probabilitas churn (indeks 1)
})

# Menampilkan customer ID dari pelanggan top 10 yang perlu diprioritaskan agar tidak churn
print("Top 10 customer yang perlu diprioritaskan agar tidak churn:")
print(top_10_customers_df)
# Out:
# Top 10 customer yang perlu diprioritaskan agar tidak churn:
#      CustomerID  Probabilitas Churn
# 920       50921            0.999949
# 385       50386            0.999904
# 785       50786            0.999903
# 315       50316            0.999869
# 347       50348            0.999847
# 197       50198            0.999810
# 488       50489            0.999810
# 889       50890            0.999767
# 989       50990            0.999737
# 613       50614            0.999671

# %% [markdown]
# Dari hasil ini kita dapat mengetahui top 10 customer dengan probabilitas churn tertinggi,seperti customer #50921 memiliki probabilitas churn sebesar 99,9%.
# Dengan ini kita bisa memprioritaskan customer tersebut agar tidak churn
#
# Predict proba berguna jika kita mempunyai keterbatasan dana untuk melakukan promosi retensi,disini kita bisa fokus terhadap customer dengan probabilitas yang tinggi

# %% [markdown]
# #### **Penerapan Model Dalam Upaya Meningkatkan Efisiensi Biaya**

# %%
# Menampilkan confussion matrix model final

plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(ytest,pred_model_final), annot=True, fmt='d', cmap='Reds', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['Actual 0', 'Actual 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# Berdasarkan confussion matrix pada hasil prediksi model final, diperoleh hasil sebagai berikut:
# - Jumlah pelanggan yang aktualnya *churn* dan diprediksi *churn* (**True Positive**) : 177 orang
# - Jumlah pelanggan yang aktualnya *churn* tetapi diprediksi tidak *churn* (**False Negative**) : 13 orang
# - Jumlah pelanggan yang aktualnya tidak *churn* tetapi diprediksi *churn* (**False Positive**) : 15 orang
# - Jumlah pelanggan yang aktualnya tidak *churn* dan diprediksi tidak *churn* (**True Negative**) : 921 orang
# ---
# Berdasarkan asumsi yang telah disampaikan pada bagian Business Understanding, kita asumsikan dampak biayanya sebagai berikut :
# - Biaya retensi per pelanggan = $27,4
# - Biaya akibat kehilangan pelanggan (Churn) = $274 per bulan per pelanggan (total pendapatan yang hilang dan biaya Customer Acquisition Cost) ([referensi](https://userpilot.com/blog/average-customer-acquisition-cost/) )
#
# Saat kita tidak menggunakan machine learning, kita tidak dapat memprediksi pelanggan yang akan Churn atau tidak. Dampaknya adalah kita cenderung untuk memberi program retensi kepada seluruh pelanggan.
#
# ---
# **Estimasi biaya tanpa model machine learning**
#
# Jumlah calon pelanggan untuk dasar perhitungan:
# - Calon pelanggan yang kita berikan program retensi (total pelanggan) = 1126 orang
# - Calon pelanggan yang aktualnya churn(TP + FN) = 177 + 13 = 190 orang
#
# Cost Estimation
# - 1126 orang x $27,4 per bulan per pelanggan + 190 orang x $274 per bulan per pelanggan = ($30852,4 + $52060) = $82914,4 per bulan
#
# **Maka total biaya yang dikeluarkan bila tidak menggunakan model machine learning adalah $82914,4 per bulan**
#
# ---
# Saat kita menggunakan machine learning, kita hanya menawarkan program retensi ke calon pelanggan yang diprediksi akan churn saja.
#
# **Estimasi biaya bila menggunakan  model machine learning**
#
# Jumlah calon pelanggan untuk dasar perhitungan:
# - Calon pelanggan yang akan diberikan program retensi (TP + FP) = 177 + 15 = 192 orang
# - Calon pelanggan yang aktualnya churn(TP + FN) = 190 orang
#
# Cost Estimation
#
# (192 orang x $27,4 per bulan per pelanggan) + (190 orang x $274 per bulan per pelanggan) =$5233,4 + $52060 = $57293,4 per bulan
#
# **Maka total biaya yang dikeluarkan bila menggunakan model machine learning adalah $57293,4 per bulan**
#
# **Total penurunan pottential loss** = $82912,4 - $57293,4 = **$25619**
#
# **Persentase penurunan** = $25619 / $82912,4 x 100 = **30,90%**
#
# **Berdasarkan data test, model final dapat membantu perusahaan menurunkan kerugian hingga 30,90% dalam sebulan menggunakan machine learning.**

# %% [markdown]
# ### **Kesimpulan Analisis**

# %% [markdown]
# Berdasarkan analisis yang telah dilakukan, berikut adalah kesimpulan yang paling tepat dan relevan:
# 1. **Status Pernikahan "Single" dan Gender "Male"  Mempengaruhi Tingkat Churn**: Pelanggan dengan status pernikahan "Single" dan Gender "Male" memiliki tingkat churn yang paling tinggi, menekankan perlunya fokus retensi khusus untuk segmen ini.
# 2. **Keluhan Pelanggan Berdampak pada Churn**: Pelanggan yang mengajukan keluhan atau complain memiliki kemungkinan besar untuk churn. Ini menunjukkan urgensi meningkatkan layanan pelanggan dan respons terhadap masalah yang dihadapi pelanggan.
# 3. **Pemberian Cashback di Awal Penting**: Cashback pada periode awal (0-2 bulan) berada di bawah median, menandakan kebutuhan untuk meningkatkan insentif awal sebagai strategi retensi pelanggan.
# 4. **Strategi Pemasaran Kupon Perlu Evaluasi**: Meskipun kupon sering digunakan oleh pelanggan, terdapat tingkat churn yang masih tinggi di tenure 1. Hal ini menunjukkan perlunya revamp atau evaluasi ulang strategi pemasaran yang melibatkan penggunaan kupon.
# 5. **Faktor Logistik dan Lokasi Penting Diperhatikan**: Jarak antara gudang dan rumah pelanggan mempengaruhi keputusan untuk churn, khususnya untuk jarak yang lebih jauh. Ini mengindikasikan perlunya optimasi logistik dan pelayanan untuk meningkatkan kepuasan pelanggan dan mengurangi alasan untuk churn.

# %% [markdown]
# ## **Rekomendasi**
# ---

# %% [markdown]
# #### **Rekomendasi Untuk Perusahaan**
# - **Audit Kualitas Produk**: Lakukan audit kualitas dan regulasi produk berdasarkan feedback pelanggan, terutama untuk kategori ”Grocery”,"Mobile Phone", dan "Fashion".
# - **Perhatian Khusus untuk Segment Pelanggan Pria dan Single**: Berikan perhatian khusus terhadap segment pelanggan laki-laki dan segment pelanggan single seperti promo cashback untuk produk (Komputer Gaming,Kemaja,dll) untuk mengurangi resiko churn.
# - **Survey Kepuasan Pelanggan**: Lakukan survei kepuasan pelanggan khusus untuk kategori produk dengan keluhan tertinggi (Grocery,Mobile Phone dan Fashion) untuk mendapatkan wawasan langsung dari pelanggan.
# - **Paket Selamat Datang Khusus**: Tawarkan insentif seperti cashback atau diskon khusus untuk pelanggan baru pada periode tenure 0-1 bulan untuk meningkatkan loyalitas pelanggan baru dan meminimalkan tingkat churn di periode awal penggunaan.
# - **Optimalkan Strategi Kupon**: Revitalisasi program kupon dengan penawaran yang lebih menarik untuk mengurangi tingkat churn pada periode tenure 0 dan 1 bulan.
# - **Diskon atau Layanan Gratis Ongkir untuk Jarak Jauh**: Tawarkan diskon atau layanan tambahan gratis biaya pengiriman untuk pelanggan yang berada dalam jarak rumah yang jauh (15+ Miles) dari gudang.
# - **Implementasi Sistem Keluhan**: Bangun sistem pelaporan keluhan yang efektif di situs web atau aplikasi perusahaan untuk memudahkan pelanggan melaporkan masalah mereka.
# - **Program Loyalitas**: Rancang program loyalitas dengan reward khusus untuk pelanggan yang telah menggunakan layanan selama periode 1 bulan keatas, untuk memotivasi mereka untuk tetap setia.
# - **Pelatihan Customer Service**: Khususnya bagi tim layanan pelanggan, berikan pelatihan mendalam tentang cara menangani keluhan, komplain, dan kritik dari pelanggan dengan cara yang profesional dan efektif.
# - **Analisis Data Periodik**: Tetapkan jadwal rutin untuk melakukan analisis data perilaku pelanggan, keluhan, dan keputusan churn untuk memastikan strategi yang diterapkan terus relevan dan efektif.
# - **Aplikasi Terhadap Model Machine Learning**: Perusahaan perlu menggunakan machine learning yang sudah dibuat, agar dapat mengurangi kerugian bagi perusahaan dengan memberikan promosi tepat sasaran kepada customer yang akan melakukan churn.
#
# Dengan menerapkan rekomendasi-rekomendasi spesifik ini, perusahaan dapat lebih fokus dalam upayanya untuk meningkatkan retensi pelanggan dan mengurangi tingkat churn.

# %% [markdown]
# #### **Rekomendasi Untuk Model**
# - **Optimalisasi Variabel**: Periksa kembali dan seleksi variabel yang paling signifikan untuk memastikan model hanya memasukkan variabel yang memberikan dampak signifikan terhadap prediksi churn.
# - **Tuning Hyperparameter**: Lanjutkan proses tuning hyperparameter pada model XGBoost untuk meningkatkan performa model, mengurangi overfitting, dan mencapai prediksi yang lebih akurat.
# - **Predict Proba** : Dengan menggunakan predict proba, kita dapat lebih fokus dan lebih terarah kepada top customer dengan probabilitas Churn yang tinggi.
# - **Interpretasi Model**: Gunakan teknik interpretasi seperti SHAP atau LIME untuk mendalaminya, sehingga dapat memahami variabel apa saja yang paling mempengaruhi keputusan churn dan bagaimana interaksi antar variabel tersebut.
# - **Pembaharuan Real-time**: Integrasikan model ke dalam sistem yang beroperasi secara real-time agar perusahaan dapat dengan cepat merespons perilaku pelanggan dan mengambil tindakan yang sesuai untuk mencegah churn.
# - **Pengoptimalan Biaya**: Dengan mempertimbangkan estimasi biaya dari model, mengkaji ulang atau melakukan penyesuaian strategi retensi pelanggan untuk memastikan alokasi sumber daya yang efektif dan efisien, serta mengurangi biaya yang tidak perlu.
# - **Feedback Loop Pelanggan**: Implementasikan mekanisme feedback dari pelanggan untuk memvalidasi prediksi dan terus memperbaiki model. Ini dapat membantu dalam memastikan model tetap relevan dan akurat seiring waktu.
#
# Dengan mengikuti rekomendasi-rekomendasi di atas, perusahaan dapat meningkatkan efektivitas strategi retensi dan mengurangi potensi churn pelanggan.

# %% [markdown]
# ## **LINK TABLEAU**
# ---

# %% [markdown]
# Link visualisasi data analisis E-Commerce Customer Churn dapat dilihat pada link dibawah ini:
# https://public.tableau.com/app/profile/ali.wafa.afif.ramdhan7404/viz/JCDS2104TableauDeltaTeam/ChurnDashboard?publish=yes
